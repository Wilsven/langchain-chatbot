# %%
# https://github.com/tomasonjo/blogs/blob/master/neo4jdocs/neo4j_support_bot.ipynb
# %pip install langchain==0.0.142 openai==0.27.4 beautifulsoup4==4.12.2 chromadb==0.3.21

# %%
import os
import dotenv

import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd

from langchain.document_loaders import (
    # GitLoader,
    # YoutubeLoader,
    # DataFrameLoader,
    UnstructuredURLLoader,
)
from langchain.text_splitter import CharacterTextSplitter

import tiktoken

# from langchain.schema import Document
from langchain.embeddings import OpenAIEmbeddings
from langchain.chat_models import ChatOpenAI
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.agents import initialize_agent, Tool

from crawl import crawl, clean, strip_content

# loads .env file with your OPENAI_API_KEY
dotenv.load_dotenv()
# Out:
# True

# %%
# Regex pattern to match a URL
HTTP_URL_PATTERN = r"^http[s]*://.+"

# Define root domain to crawl
DOMAIN = "aba.com.sg"
FULL_URL = "https://www.aba.com.sg/"

# %% [markdown]
# ### Embedding documents for the first time

# %%
seen = crawl(FULL_URL)
print(len(seen))
# Out:
# https://www.aba.com.sg/
# https://www.aba.com.sg/privacy-policy
# https://www.aba.com.sg/sfec
# https://www.aba.com.sg/post/gst-rate-change-with-effect-from-01-january-2023
# https://www.aba.com.sg/blog/categories/smes-go-digital
# https://www.aba.com.sg/post/sme-go-digital-programme
# https://www.aba.com.sg/blog/categories/accounting-software
# https://www.aba.com.sg/advisory-services
# https://www.aba.com.sg/edg
# https://www.aba.com.sg/home
# https://www.aba.com.sg/post/business-times-feature-how-cloud-accounting-helped-this-practice-s-client-make-the-perfect-brew
# https://www.aba.com.sg/./#comp-kqbq7zqh1
# https://www.aba.com.sg/xero
# https://www.aba.com.sg/productivity-solutions-grant-psg
# https://www.aba.com.sg/post/quickbooks-vs-xero-2020-comparing-cloud-based-accounting-software
# https://www.aba.com.sg/post/hopping-onto-the-train-of-digital-transformation
# https://www.aba.com.sg/software-solutions
# https://www.aba.com.sg/html-sitemap
# https://www.aba.com.sg
# https://www.aba.com.sg/blog
# https://www.aba.com.sg/post/how-to-contact-xero-support
# https://www.aba.com.sg/post/3-steps-for-seamless-digital-transformation-in-the-21st-century
# https://www.aba.com.sg/post/gst-2020-simplified-reverse-charges-and-overseas-vendor-registration
# https://www.aba.com.sg/services
# https://www.aba.com.sg/post/invoicenow
# https://www.aba.com.sg/post/quickbooks-vs-xero
# https://www.aba.com.sg/psg
# https://www.aba.com.sg/accountingservices
# https://www.aba.com.sg/./#comp-kqbq7zqa1
# https://www.aba.com.sg/./#comp-kqbq7zpt
# https://www.aba.com.sg/quickbooks-start-digital
# https://www.aba.com.sg/grants
# https://www.aba.com.sg/xero-psg
# https://www.aba.com.sg/qbo-psg
# https://www.aba.com.sg/post/how-to-contact-quickbooks-online-qbo-support
# https://www.aba.com.sg/./#comp-kqbq7zq12
# https://www.aba.com.sg/invoicenow
# https://www.aba.com.sg/./#comp-kqj5371n
# https://www.aba.com.sg/./#comp-kqj5370r
# https://www.aba.com.sg/./#comp-kqj5371a
# https://www.aba.com.sg/contact-us
# https://www.aba.com.sg/./#comp-l3vbi3yq
# https://www.aba.com.sg/./#comp-l3vbdhfo
# https://www.aba.com.sg/corporate-services
# 44

# %%
clean = clean(seen)
print(len(clean))

# %%
urls = list(clean)

loader = UnstructuredURLLoader(urls=urls)
data = loader.load()
print(len(data))
# Out:
# 44

# %%
for d in data:
    new_content = strip_content(d.page_content)
    d.page_content = new_content

# %%
# Define text chunk strategy
splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200, separator=" ")
# Split documents into chunks
data_split = splitter.split_documents(data)
print(len(data_split))
# Out:
# 139

# %%
data_split  # due to nature of website, there are duplicate documents (needs preprocessing)
# Out:
# [Document(page_content='CORPORATE SERVICES  Unity results in phenomenal growth. Outsource areas which occupy your time to us so that you can improve business efficiency.  Find out more  Taxation  Taxation  Our full range of services includes:  Corporate tax compliance and advisory  GST registration, filing, compliance and advisory  Advisory on various business structures and their tax implications  Advisory on sole proprietorship, partnership, corporate and their tax implications  Conversion of business structures and its Tax/GST implications  Managing IRAS audit and investigations  Our taxation services are committed to minimising your tax liability while complying with the latest tax and statutory requirements to help you make well informed and ideal tax decisions.  Accountng  Accounting  Our accounting services include preparing full sets of financial statements based on the latest accounting standards and regulations to reduce your accounting chores.  Our full range of services includes the preparation of', metadata={'source': 'https://www.aba.com.sg/corporate-services'}),
#  Document(page_content="include preparing full sets of financial statements based on the latest accounting standards and regulations to reduce your accounting chores.  Our full range of services includes the preparation of :  Profit & Loss statement  Balance sheet statement  Bank reconciliation  Director's & Financial Statements  Corporate Secretary  Corporate Secretary  As a registered Filing Agent and Qualified Individual for corporate secretary, we offer incorporation services for start-ups and corporate secretarial services to support you throughout the course of your business.  Our full range of services include:  Incorporation of companies  Registration of business names  Drafting annual resolutions and minutes  Filing annual returns and corporate secretarial documents with ACRA  CFO Insights  CFO Insights  Our experienced in-house Chartered Accountants with more than 20 years of experience in Multinational Corporations (MNCs) and Small Medium Enterprises (SMEs) will provide you with a holistic and", metadata={'source': 'https://www.aba.com.sg/corporate-services'}),
#  Document(page_content='Our experienced in-house Chartered Accountants with more than 20 years of experience in Multinational Corporations (MNCs) and Small Medium Enterprises (SMEs) will provide you with a holistic and integrated CFO insight to assist you in propelling your business.', metadata={'source': 'https://www.aba.com.sg/corporate-services'}),
#  Document(page_content='Dec 13, 2020  The New Normal for Small and Medium Enterprises (SMEs) | SMEs Go Digital Programme  The year 2020 passed by in a flurry due to the unprecedented circumstances on a scale that the world has never experienced. Due to these...  298 views', metadata={'source': 'https://www.aba.com.sg/blog/categories/accounting-software'}),
#  Document(page_content='Jun 16, 20213 min read  QuickBooks vs Xero - Comparing Cloud-based Accounting Software  At the mention of cloud based accounting software, Xero and QuickBooks Online immediately come to mind. As leaders in the market, these two solution providers offer a somewhat equally comprehensive suite of functions, features and packages that cater to the needs of businesses of various sizes. So, how do you decide which of the two fits the bill?  As ONE of the companies in Singapore that qualifies as a Productivity Solutions Grant (PSG) pre-approved vendor for both QuickBooks (InvoiceNow) and Xero with up to 80% subsidy, we have compared the two for you so that you don’t have to do it yourself!  Points of clarification:  Though many of the features seem similar, that didn’t use to be the case. QuickBooks had the head start in being IRAS compliant, whereas Xero was the first mover into establishing the bank feed feature. Over time, these differences smoothed out, resulting in the similarities', metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero-2020-comparing-cloud-based-accounting-software'}),
#  Document(page_content='had the head start in being IRAS compliant, whereas Xero was the first mover into establishing the bank feed feature. Over time, these differences smoothed out, resulting in the similarities we see today in these two remarkable software solutions.  However, the two still have their distinctive strengths:  QuickBooks has a comprehensive list of built-in templates that can be customised to a certain degree. Some of these include sales quotation, sales invoice and statement of accounts. This could be a massive time-saver for your company as there is no longer a need to create standard business documents from scratch and making them look neat.  Xero’s financial and management reporting features are rather robust. This feature can give management a highly detailed breakdown of sales and performance across different metrics of their choice (i.e. segment, product). Meanwhile, QuickBooks has an arsenal of advanced reporting options that allows management to track the efficiency and', metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero-2020-comparing-cloud-based-accounting-software'}),
#  Document(page_content="and performance across different metrics of their choice (i.e. segment, product). Meanwhile, QuickBooks has an arsenal of advanced reporting options that allows management to track the efficiency and effectiveness of various business processes.  Xero has a plethora of applications and add-ons to choose from. It is almost certain that you would find one that fits your business needs to a tee. That however, comes at the cost of the time spend sieving through hundreds of similar looking applications.  On the other hand, while QuickBooks supports fewer add-ons, they are distributed across a wide enough variety of categories and are most likely sufficient for most businesses.  Now that we've done the work for you, the ball is in your court. At the end of the day, both solutions have their defining strengths, which allow them to cater to different business needs. To reap the optimal benefits, new users should engage professionals to ease their migration to cloud-based solution as experienced", metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero-2020-comparing-cloud-based-accounting-software'}),
#  Document(page_content='strengths, which allow them to cater to different business needs. To reap the optimal benefits, new users should engage professionals to ease their migration to cloud-based solution as experienced professionals are able to give valuable tips, ensuring a smooth transition. Regardless, cloud based accounting software can be very powerful and time-saving, allowing you to focus more on other essential business functions, so it pays to choose carefully. Finally, with digitalisation transforming every sector of Singapore’s economy, it is essential that your business benefits from such technologies to improve operations and generate new revenue. If you require further clarification about which accounting software solution might be best suited to your business needs, feel free to email us so that we can assign a consultant to follow up with your inquiries. You may also be able to enjoy up to 80% subsidy when you engage us for the implementation and migration into QuickBooks or Xero.  The', metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero-2020-comparing-cloud-based-accounting-software'}),
#  Document(page_content='that we can assign a consultant to follow up with your inquiries. You may also be able to enjoy up to 80% subsidy when you engage us for the implementation and migration into QuickBooks or Xero.  The contents of the blog only provide information on the differences between Quickbooks and Xero. Please conduct your own due diligence and consult your professional accountant before making any project decision.  0 views  0 comments  Post not marked as liked  At the mention of cloud based accounting software, Xero and QuickBooks Online immediately come to mind. As leaders in the market, these two solution providers offer a somewhat equally comprehensive suite of functions, features and packages that cater to the needs of businesses of various sizes. So, how do you decide which of the two fits the bill?  As ONE of the companies in Singapore that qualifies as a Productivity Solutions Grant (PSG) pre-approved vendor for both QuickBooks (InvoiceNow) and Xero with up to 80% subsidy, we have', metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero-2020-comparing-cloud-based-accounting-software'}),
#  Document(page_content='the bill?  As ONE of the companies in Singapore that qualifies as a Productivity Solutions Grant (PSG) pre-approved vendor for both QuickBooks (InvoiceNow) and Xero with up to 80% subsidy, we have compared the two for you so that you don’t have to do it yourself!  Points of clarification:  Though many of the features seem similar, that didn’t use to be the case. QuickBooks had the head start in being IRAS compliant, whereas Xero was the first mover into establishing the bank feed feature. Over time, these differences smoothed out, resulting in the similarities we see today in these two remarkable software solutions.  However, the two still have their distinctive strengths:  QuickBooks has a comprehensive list of built-in templates that can be customised to a certain degree. Some of these include sales quotation, sales invoice and statement of accounts. This could be a massive time-saver for your company as there is no longer a need to create standard business documents from scratch and', metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero-2020-comparing-cloud-based-accounting-software'}),
#  Document(page_content='sales quotation, sales invoice and statement of accounts. This could be a massive time-saver for your company as there is no longer a need to create standard business documents from scratch and making them look neat.  Xero’s financial and management reporting features are rather robust. This feature can give management a highly detailed breakdown of sales and performance across different metrics of their choice (i.e. segment, product). Meanwhile, QuickBooks has an arsenal of advanced reporting options that allows management to track the efficiency and effectiveness of various business processes.  Xero has a plethora of applications and add-ons to choose from. It is almost certain that you would find one that fits your business needs to a tee. That however, comes at the cost of the time spend sieving through hundreds of similar looking applications.  On the other hand, while QuickBooks supports fewer add-ons, they are distributed across a wide enough variety of categories and are most', metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero-2020-comparing-cloud-based-accounting-software'}),
#  Document(page_content="sieving through hundreds of similar looking applications.  On the other hand, while QuickBooks supports fewer add-ons, they are distributed across a wide enough variety of categories and are most likely sufficient for most businesses.  Now that we've done the work for you, the ball is in your court. At the end of the day, both solutions have their defining strengths, which allow them to cater to different business needs. To reap the optimal benefits, new users should engage professionals to ease their migration to cloud-based solution as experienced professionals are able to give valuable tips, ensuring a smooth transition. Regardless, cloud based accounting software can be very powerful and time-saving, allowing you to focus more on other essential business functions, so it pays to choose carefully. Finally, with digitalisation transforming every sector of Singapore’s economy, it is essential that your business benefits from such technologies to improve operations and generate new", metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero-2020-comparing-cloud-based-accounting-software'}),
#  Document(page_content='carefully. Finally, with digitalisation transforming every sector of Singapore’s economy, it is essential that your business benefits from such technologies to improve operations and generate new revenue. If you require further clarification about which accounting software solution might be best suited to your business needs, feel free to email us so that we can assign a consultant to follow up with your inquiries. You may also be able to enjoy up to 80% subsidy when you engage us for the implementation and migration into QuickBooks or Xero.  The contents of the blog only provide information on the differences between Quickbooks and Xero. Please conduct your own due diligence and consult your professional accountant before making any project decision.', metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero-2020-comparing-cloud-based-accounting-software'}),
#  Document(page_content='How Can We Help?  Sales Inquiries  Speak to our friendly sales consultants to find out more on our digital accounting solution or other accounting services.  Get In Touch  Support  Facing difficulties?  Let our professional experts help you.  Get In Touch  Form  Sales Inquiry  We will get back to you as soon as possible!  I am interested to register for the live demo session.  I want to find out more about PSG Grant  I want to apply for DBS Start Digital  By clicking, you agree to our Privacy Policy  Submit      Anchor 1  Locate Us  Location:  2 Kallang Ave #09-26,  CT Hub, Singapore 339407  Opening Hours:  Monday - Friday: 9 a.m. - 6 p.m.', metadata={'source': 'https://www.aba.com.sg/contact-us'}),
#  Document(page_content="Business Times Feature: How cloud accounting helped this practice's client make the perfect brew  Nov 24, 2022    3 min  Business Times Feature: How cloud accounting helped this practice's client make the perfect brew  26  2 likes. Post not marked as liked  GST Rate Change with effect from 01 January 2023  Nov 2, 2022    2 min  GST Rate Change with effect from 01 January 2023  600  3 likes. Post not marked as liked  How to contact Quickbooks Online (QBO) Support?  Jan 26, 2022    1 min  How to contact Quickbooks Online (QBO) Support?  222  2 likes. Post not marked as liked", metadata={'source': 'https://www.aba.com.sg/./#comp-l3vbdhfo'}),
#  Document(page_content='Jun 16, 20213 min read  QuickBooks vs Xero - Comparing Cloud-based Accounting Software  At the mention of cloud based accounting software, Xero and QuickBooks Online immediately come to mind. As leaders in the market, these two solution providers offer a somewhat equally comprehensive suite of functions, features and packages that cater to the needs of businesses of various sizes. So, how do you decide which of the two fits the bill?  As ONE of the companies in Singapore that qualifies as a Productivity Solutions Grant (PSG) pre-approved vendor for both QuickBooks (InvoiceNow) and Xero with up to 80% subsidy, we have compared the two for you so that you don’t have to do it yourself!  Points of clarification:  Though many of the features seem similar, that didn’t use to be the case. QuickBooks had the head start in being IRAS compliant, whereas Xero was the first mover into establishing the bank feed feature. Over time, these differences smoothed out, resulting in the similarities', metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero'}),
#  Document(page_content='had the head start in being IRAS compliant, whereas Xero was the first mover into establishing the bank feed feature. Over time, these differences smoothed out, resulting in the similarities we see today in these two remarkable software solutions.  However, the two still have their distinctive strengths:  QuickBooks has a comprehensive list of built-in templates that can be customised to a certain degree. Some of these include sales quotation, sales invoice and statement of accounts. This could be a massive time-saver for your company as there is no longer a need to create standard business documents from scratch and making them look neat.  Xero’s financial and management reporting features are rather robust. This feature can give management a highly detailed breakdown of sales and performance across different metrics of their choice (i.e. segment, product). Meanwhile, QuickBooks has an arsenal of advanced reporting options that allows management to track the efficiency and', metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero'}),
#  Document(page_content="and performance across different metrics of their choice (i.e. segment, product). Meanwhile, QuickBooks has an arsenal of advanced reporting options that allows management to track the efficiency and effectiveness of various business processes.  Xero has a plethora of applications and add-ons to choose from. It is almost certain that you would find one that fits your business needs to a tee. That however, comes at the cost of the time spend sieving through hundreds of similar looking applications.  On the other hand, while QuickBooks supports fewer add-ons, they are distributed across a wide enough variety of categories and are most likely sufficient for most businesses.  Now that we've done the work for you, the ball is in your court. At the end of the day, both solutions have their defining strengths, which allow them to cater to different business needs. To reap the optimal benefits, new users should engage professionals to ease their migration to cloud-based solution as experienced", metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero'}),
#  Document(page_content='strengths, which allow them to cater to different business needs. To reap the optimal benefits, new users should engage professionals to ease their migration to cloud-based solution as experienced professionals are able to give valuable tips, ensuring a smooth transition. Regardless, cloud based accounting software can be very powerful and time-saving, allowing you to focus more on other essential business functions, so it pays to choose carefully. Finally, with digitalisation transforming every sector of Singapore’s economy, it is essential that your business benefits from such technologies to improve operations and generate new revenue. If you require further clarification about which accounting software solution might be best suited to your business needs, feel free to email us so that we can assign a consultant to follow up with your inquiries. You may also be able to enjoy up to 80% subsidy when you engage us for the implementation and migration into QuickBooks or Xero.  The', metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero'}),
#  Document(page_content='that we can assign a consultant to follow up with your inquiries. You may also be able to enjoy up to 80% subsidy when you engage us for the implementation and migration into QuickBooks or Xero.  The contents of the blog only provide information on the differences between Quickbooks and Xero. Please conduct your own due diligence and consult your professional accountant before making any project decision.  0 views  0 comments  Post not marked as liked  At the mention of cloud based accounting software, Xero and QuickBooks Online immediately come to mind. As leaders in the market, these two solution providers offer a somewhat equally comprehensive suite of functions, features and packages that cater to the needs of businesses of various sizes. So, how do you decide which of the two fits the bill?  As ONE of the companies in Singapore that qualifies as a Productivity Solutions Grant (PSG) pre-approved vendor for both QuickBooks (InvoiceNow) and Xero with up to 80% subsidy, we have', metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero'}),
#  Document(page_content='the bill?  As ONE of the companies in Singapore that qualifies as a Productivity Solutions Grant (PSG) pre-approved vendor for both QuickBooks (InvoiceNow) and Xero with up to 80% subsidy, we have compared the two for you so that you don’t have to do it yourself!  Points of clarification:  Though many of the features seem similar, that didn’t use to be the case. QuickBooks had the head start in being IRAS compliant, whereas Xero was the first mover into establishing the bank feed feature. Over time, these differences smoothed out, resulting in the similarities we see today in these two remarkable software solutions.  However, the two still have their distinctive strengths:  QuickBooks has a comprehensive list of built-in templates that can be customised to a certain degree. Some of these include sales quotation, sales invoice and statement of accounts. This could be a massive time-saver for your company as there is no longer a need to create standard business documents from scratch and', metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero'}),
#  Document(page_content='sales quotation, sales invoice and statement of accounts. This could be a massive time-saver for your company as there is no longer a need to create standard business documents from scratch and making them look neat.  Xero’s financial and management reporting features are rather robust. This feature can give management a highly detailed breakdown of sales and performance across different metrics of their choice (i.e. segment, product). Meanwhile, QuickBooks has an arsenal of advanced reporting options that allows management to track the efficiency and effectiveness of various business processes.  Xero has a plethora of applications and add-ons to choose from. It is almost certain that you would find one that fits your business needs to a tee. That however, comes at the cost of the time spend sieving through hundreds of similar looking applications.  On the other hand, while QuickBooks supports fewer add-ons, they are distributed across a wide enough variety of categories and are most', metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero'}),
#  Document(page_content="sieving through hundreds of similar looking applications.  On the other hand, while QuickBooks supports fewer add-ons, they are distributed across a wide enough variety of categories and are most likely sufficient for most businesses.  Now that we've done the work for you, the ball is in your court. At the end of the day, both solutions have their defining strengths, which allow them to cater to different business needs. To reap the optimal benefits, new users should engage professionals to ease their migration to cloud-based solution as experienced professionals are able to give valuable tips, ensuring a smooth transition. Regardless, cloud based accounting software can be very powerful and time-saving, allowing you to focus more on other essential business functions, so it pays to choose carefully. Finally, with digitalisation transforming every sector of Singapore’s economy, it is essential that your business benefits from such technologies to improve operations and generate new", metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero'}),
#  Document(page_content='carefully. Finally, with digitalisation transforming every sector of Singapore’s economy, it is essential that your business benefits from such technologies to improve operations and generate new revenue. If you require further clarification about which accounting software solution might be best suited to your business needs, feel free to email us so that we can assign a consultant to follow up with your inquiries. You may also be able to enjoy up to 80% subsidy when you engage us for the implementation and migration into QuickBooks or Xero.  The contents of the blog only provide information on the differences between Quickbooks and Xero. Please conduct your own due diligence and consult your professional accountant before making any project decision.', metadata={'source': 'https://www.aba.com.sg/post/quickbooks-vs-xero'}),
#  Document(page_content='Accounting Software with 50%\xa0PSG Grant Xero & QuickBooks  Contact Us  InvoiceNow Sign Up Form  Submit  By clicking, you agree to our\xa0Privacy Policy  Benefits of InvoiceNow  E-Invoicing Benefits  Improve Efficiency  Avoid error-prone manual data entry  Streamline processes  Get Paid Faster  Invoice delivered immediately  Results in faster invoice processing, validation and payment times  Reduce cost  No more printing of paper invoices  Easy storage and retrieval online  Set up Peppol  How to set up InvoiceNow\xa0in Xero  Step 1  Engage Abundant Accounting as your Peppol-ready solution provider        If you would like to know more InvoiceNow,\xa0click here to contact us.  Brought to you by', metadata={'source': 'https://www.aba.com.sg/invoicenow'}),
#  Document(page_content='Services: Services  Home: Services  OUR SERVICES  Corporate Advisory  Management Consultancy  Accounting  Taxation  Corporate Secretary  CFO insights  Digital Accounting System  Cloud-Based Accounting Systems  Advisory  Setting Up New Business  IT Infrastructure\u200b & Support  #comp-l3b7wgm9 svg [data-color="1"] {fill: #FFFFFF;}Setting up New businesses  #comp-l3b7wgmf svg [data-color="1"] {fill: #FFFFFF;}Cloud-based accounting system  #comp-l3b7wgmk svg [data-color="1"] {fill: #FFFFFF;}Business advisory  Cloud-Based HR & POS Systems  Accounting  #comp-l3b7wgnb svg [data-color="1"] {fill: #FFFFFF;}Accounting  Audit Services', metadata={'source': 'https://www.aba.com.sg/services'}),
#  Document(page_content="Business Times Feature: How cloud accounting helped this practice's client make the perfect brew  Nov 24, 2022    3 min  Business Times Feature: How cloud accounting helped this practice's client make the perfect brew  26  2 likes. Post not marked as liked  GST Rate Change with effect from 01 January 2023  Nov 2, 2022    2 min  GST Rate Change with effect from 01 January 2023  600  3 likes. Post not marked as liked  How to contact Quickbooks Online (QBO) Support?  Jan 26, 2022    1 min  How to contact Quickbooks Online (QBO) Support?  222  2 likes. Post not marked as liked", metadata={'source': 'https://www.aba.com.sg/./#comp-kqbq7zq12'}),
#  Document(page_content='Jan 26, 20221 min read  How to contact Quickbooks Online (QBO) Support?  Did you know that you are entitled to free, unlimited 24/7 support if you\'re subscribed to QBO? In this guide, we\'ll be showing you how you can access and contact QBO Support directly.  Click on this link or copy the URL below into your address bar. https://help.quickbooks.intuit.com/en_SG/contact  You will be prompted to fill in some information regarding your query. Fill up the field accordingly and click on "Search", QBO will direct you to some useful resources.  If you are still unable to resolve your query with the resources provided, scroll to the bottom of the page and click on "Start a Message".  This will open up a pop-up of a live chat with a QBO staff.  In the pop-up, fill in the relevant information then click on "Start Chat". QBO will connect you with one of their support staff for a live chat.  0 views  0 comments  Post not marked as liked  Did you know that you are entitled to free, unlimited', metadata={'source': 'https://www.aba.com.sg/post/how-to-contact-quickbooks-online-qbo-support'}),
#  Document(page_content='then click on "Start Chat". QBO will connect you with one of their support staff for a live chat.  0 views  0 comments  Post not marked as liked  Did you know that you are entitled to free, unlimited 24/7 support if you\'re subscribed to QBO? In this guide, we\'ll be showing you how you can access and contact QBO Support directly.  Click on this link or copy the URL below into your address bar. https://help.quickbooks.intuit.com/en_SG/contact  You will be prompted to fill in some information regarding your query. Fill up the field accordingly and click on "Search", QBO will direct you to some useful resources.  If you are still unable to resolve your query with the resources provided, scroll to the bottom of the page and click on "Start a Message".  This will open up a pop-up of a live chat with a QBO staff.  In the pop-up, fill in the relevant information then click on "Start Chat". QBO will connect you with one of their support staff for a live chat.', metadata={'source': 'https://www.aba.com.sg/post/how-to-contact-quickbooks-online-qbo-support'}),
#  Document(page_content='System solutions  digital  Up to 50% on PSG for Quickbooks Online (QBO)*  Terms and conditions apply. Click here to find out more about PSG.  * Eligible employers for SkillsFuture Enterprise Credit (SFEC) will receive a one-off $10,000 credit to cover up to 90% of the remaining cost of the QBO PSG package.  Supported By:  In Support Of:  PSG  Our PSG Pre-approved Packages for Quickbooks Online (QBO) Get subsidies of up to 50% (PSG)  Sales and Accounting Module Set Up$1630After 50% PSG12-Month QBO Plus License (worth SGD560)  Complimentary QBO Support  Access to QBO Mobile AppImplementation of QBO  Set up of Company Profile  Integration to InvoiceNow  \u200b  Chart of Accounts  \u200b  GST Set-up  \xa0  Set up Sales FormTraining by AccountantsSales, Accounting and Inventory Module$2330After 50% PSG12-Month QBO Plus License (worth SGD560)  Complimentary QBO Support  Access to QBO Mobile AppImplementation of QBO  Set up of Company Profile  Integration to InvoiceNow  Chart of Accounts  GST Set-up', metadata={'source': 'https://www.aba.com.sg/qbo-psg'}),
#  Document(page_content='QBO Plus License (worth SGD560)  Complimentary QBO Support  Access to QBO Mobile AppImplementation of QBO  Set up of Company Profile  Integration to InvoiceNow  Chart of Accounts  GST Set-up  \xa0  Customised Sales Form \xa0Data Migration  Customer/Supplier Database  Balance Sheet for Two Financial Years  Profit and Loss for Two Financial YearsTraining and Consultancy by AccountantsSetup with Detailed Migration$2880After 50% PSG12-Month QBO Plus License (worth SGD560)  Complimentary QBO Support  Access to QBO Mobile AppImplementation of QBO  Set up of Company Profile  Integration to InvoiceNow  Chart of Accounts  GST Set-up  Customised Sales FormData Migration  Customer/Supplier Database  Balance Sheet for Two Financial Years  Profit and Loss for Two Financial YearsDetailed Migration  (Please contact us to find out more)Training and Consultancy by Accountants  Eligible employers for Skills Future Enterprise Credit (SFEC) may receive a one-off $10,000 credit to cover up to 90% of the out of', metadata={'source': 'https://www.aba.com.sg/qbo-psg'}),
#  Document(page_content='contact us to find out more)Training and Consultancy by Accountants  Eligible employers for Skills Future Enterprise Credit (SFEC) may receive a one-off $10,000 credit to cover up to 90% of the out of pocket expenses on qualifying costs.  Sales and Accounting Module Set Up  $1630  After 50% PSG  12-Month QBO Plus License (worth SGD560)  Complimentary QBO Support  Access to QBO Mobile App  Implementation of QBO  Set up of Company Profile  Integration to InvoiceNow  Chart of Accounts  GST Set-up  Set up Sales Form  Training by Accountants  Sales, Accounting and Inventory Module  $2330  After 50% PSG  12-Month QBO Plus License (worth SGD560)  Complimentary QBO Support  Access to QBO Mobile App  Implementation of QBO  Set up of Company Profile  Integration to InvoiceNow  Chart of Accounts  GST Set-up  Customised Sales Form  Data Migration  Customer/Supplier Database  Balance Sheet for Two Financial Years  Profit and Loss for Two Financial Years  Training and Consultancy by Accountants', metadata={'source': 'https://www.aba.com.sg/qbo-psg'}),
#  Document(page_content='GST Set-up  Customised Sales Form  Data Migration  Customer/Supplier Database  Balance Sheet for Two Financial Years  Profit and Loss for Two Financial Years  Training and Consultancy by Accountants  Setup with Detailed Migration  $2880  After 50% PSG  12-Month QBO Plus License (worth SGD560)  Complimentary QBO Support  Access to QBO Mobile App  Implementation of QBO  Set up of Company Profile  Integration to InvoiceNow  Chart of Accounts  GST Set-up  Customised Sales Form  Data Migration  Customer/Supplier Database  Balance Sheet for Two Financial Years  Profit and Loss for Two Financial Years  Detailed Migration  (Please contact us to find out more)  Training and Consultancy by Accountants  All our customers are happy with our implementation services by a pool of passionate IT and accounting professionals as we strongly believe we are able to impact your life with the automated accounting system with at least 30% productivity achieved.  Get a Quote  What is Quickbooks Online (QBO)?', metadata={'source': 'https://www.aba.com.sg/qbo-psg'}),
#  Document(page_content="professionals as we strongly believe we are able to impact your life with the automated accounting system with at least 30% productivity achieved.  Get a Quote  What is Quickbooks Online (QBO)?  Simply put, QBO is a cloud-based online accounting software.  What this means for your business is that you will be able to share access to your financial information with your team/accountant/bookkeeper as long as they have internet access.  Gone are the days where your accounting team have to work in silos. Now, your team will be able to work together in the cloud and business owners will be able to get the latest updates on the business' financial health.  Of course, there are more than just the benefit of working together using QBO.  For more details, read our blog post on the benefits of using Cloud Accounting Software like QBO.  Not sure if QBO works for you? Speak to our advisors to find out more.", metadata={'source': 'https://www.aba.com.sg/qbo-psg'}),
#  Document(page_content='Dec 13, 20202 min read  The New Normal for Small and Medium Enterprises (SMEs) | SMEs Go Digital Programme  The year 2020 passed by in a flurry due to the unprecedented circumstances on a scale that the world has never experienced. Due to these overwhelming times, it may be difficult to some to remember life before the Covid-19 pandemic and lockdown. However, even before the outbreak, the age of digitalisation has already been creeping up on the accounting industry. As of right now, with working from home being a certainty for the next few years due to the pandemic, it has accelerated the digitalisation process across all industries, especially accounting and its practices. In fact, working from home is probably going to be a staple in the working culture for years to come.  With that in mind, IMDA has begun taking steps to spur and encourage the growth of digitalisation even further with its SMEs Go Digital initiative. They will majorly subsidise the pre-approved IT solutions for', metadata={'source': 'https://www.aba.com.sg/post/sme-go-digital-programme'}),
#  Document(page_content="in mind, IMDA has begun taking steps to spur and encourage the growth of digitalisation even further with its SMEs Go Digital initiative. They will majorly subsidise the pre-approved IT solutions for small and medium enterprises (SMEs) which make up two thirds of Singapore's workforce. They do so because the benefits that the pre-approved IT solutions bring are expansive, allowing SMEs to leverage on digital technologies to grow amidst the pandemic.  Since our incorporation as an IT solutions company, we have been helping companies set up their systems and seamlessly transition them into cloud based accounting. With our excellent 8 year track record, our professional accountants are well equipped to provide these services so you can reap the countless benefits for you and your firm. Below are just a few benefits that could boost your company :  Drastic reduction in manual processes for users  Ease of retrieval for invoices/ No hard copies for invoices  Shorter learning curves with our", metadata={'source': 'https://www.aba.com.sg/post/sme-go-digital-programme'}),
#  Document(page_content='are just a few benefits that could boost your company :  Drastic reduction in manual processes for users  Ease of retrieval for invoices/ No hard copies for invoices  Shorter learning curves with our professional training  Professional design of reports to facilitate decision making  Enhance revenue growth by rewarding good performances  Control Costing gives valuable insights to areas with high costs  Tax planning/savings  SMEs Go Digital  •  Accounting Software  0 views  0 comments  Post not marked as liked  The year 2020 passed by in a flurry due to the unprecedented circumstances on a scale that the world has never experienced. Due to these overwhelming times, it may be difficult to some to remember life before the Covid-19 pandemic and lockdown. However, even before the outbreak, the age of digitalisation has already been creeping up on the accounting industry. As of right now, with working from home being a certainty for the next few years due to the pandemic, it has accelerated', metadata={'source': 'https://www.aba.com.sg/post/sme-go-digital-programme'}),
#  Document(page_content="age of digitalisation has already been creeping up on the accounting industry. As of right now, with working from home being a certainty for the next few years due to the pandemic, it has accelerated the digitalisation process across all industries, especially accounting and its practices. In fact, working from home is probably going to be a staple in the working culture for years to come.  With that in mind, IMDA has begun taking steps to spur and encourage the growth of digitalisation even further with its SMEs Go Digital initiative. They will majorly subsidise the pre-approved IT solutions for small and medium enterprises (SMEs) which make up two thirds of Singapore's workforce. They do so because the benefits that the pre-approved IT solutions bring are expansive, allowing SMEs to leverage on digital technologies to grow amidst the pandemic.  Since our incorporation as an IT solutions company, we have been helping companies set up their systems and seamlessly transition them into", metadata={'source': 'https://www.aba.com.sg/post/sme-go-digital-programme'}),
#  Document(page_content='on digital technologies to grow amidst the pandemic.  Since our incorporation as an IT solutions company, we have been helping companies set up their systems and seamlessly transition them into cloud based accounting. With our excellent 8 year track record, our professional accountants are well equipped to provide these services so you can reap the countless benefits for you and your firm. Below are just a few benefits that could boost your company :  Drastic reduction in manual processes for users  Ease of retrieval for invoices/ No hard copies for invoices  Shorter learning curves with our professional training  Professional design of reports to facilitate decision making  Enhance revenue growth by rewarding good performances  Control Costing gives valuable insights to areas with high costs  Tax planning/savings', metadata={'source': 'https://www.aba.com.sg/post/sme-go-digital-programme'}),
#  Document(page_content="Business Times Feature: How cloud accounting helped this practice's client make the perfect brew  Nov 24, 2022    3 min  Business Times Feature: How cloud accounting helped this practice's client make the perfect brew  26  2 likes. Post not marked as liked  GST Rate Change with effect from 01 January 2023  Nov 2, 2022    2 min  GST Rate Change with effect from 01 January 2023  600  3 likes. Post not marked as liked  How to contact Quickbooks Online (QBO) Support?  Jan 26, 2022    1 min  How to contact Quickbooks Online (QBO) Support?  222  2 likes. Post not marked as liked", metadata={'source': 'https://www.aba.com.sg/software-solutions'}),
#  Document(page_content='System solutions  digital  Up to 50% on PSG for Xero Accounting Software*  Terms and conditions apply. Click here to find out more about PSG.  * Eligible employers for SkillsFuture Enterprise Credit (SFEC) will receive a one-off $10,000 credit to cover up to 90% of the remaining cost of the Xero PSG package.  An initiative of:  In Support Of:  PSG  Our PSG Pre-approved Packages for Xero Get subsidies of up to 50% (PSG)  Sales and Accounting Module Set Up$1710After 50% PSG12-Month Xero Premium License (worth SGD720)  Complimentary Xero Support  Access to Xero Mobile AppImplementation of Xero  Set up of Company Profile  Integration to InvoiceNow  \u200b  Chart of Accounts  \u200b  GST Set-up  \xa0  Set up Sales FormTraining by AccountantsSales, Accounting and Inventory Module$2410After 50% PSG12-Month Xero Premium License (worth SGD720)  Complimentary Xero Support  Access to Xero Mobile AppImplementation of Xero  Set up of Company Profile  Integration to InvoiceNow  Chart of Accounts  GST Set-up  \u200b', metadata={'source': 'https://www.aba.com.sg/xero-psg'}),
#  Document(page_content='Premium License (worth SGD720)  Complimentary Xero Support  Access to Xero Mobile AppImplementation of Xero  Set up of Company Profile  Integration to InvoiceNow  Chart of Accounts  GST Set-up  \u200b  Customised Sales FormData Migration  Customer/Supplier Database  Balance Sheet for Two Financial Years  Profit and Loss for Two Financial YearsTraining and Consultancy by AccountantsSetup with Detailed Migration$2960After 50% PSG12-Month Xero Premium License (worth SGD720)  Complimentary Xero Support  Access to Xero Mobile AppImplementation of Xero  Set up of Company Profile  Integration to InvoiceNow  Chart of Accounts  GST Set-up  Customised Sales FormData Migration  Customer/Supplier Database  Balance Sheet for Two Financial Years  Profit and Loss for Two Financial YearsDetailed Migration  (Please contact us to find out more)Training and Consultancy by Accountants  Eligible employers for Skills Future Enterprise Credit (SFEC) may receive a one-off $10,000 credit to cover up to 90% of the', metadata={'source': 'https://www.aba.com.sg/xero-psg'}),
#  Document(page_content='contact us to find out more)Training and Consultancy by Accountants  Eligible employers for Skills Future Enterprise Credit (SFEC) may receive a one-off $10,000 credit to cover up to 90% of the out of pocket expenses on qualifying costs.  Sales and Accounting Module Set Up  $1710  After 50% PSG  12-Month Xero Premium License (worth SGD720)  Complimentary Xero Support  Access to Xero Mobile App  Implementation of Xero  Set up of Company Profile  Integration to InvoiceNow  Chart of Accounts  GST Set-up  Set up Sales Form  Training by Accountants  Sales, Accounting and Inventory Module  $2410  After 50% PSG  12-Month Xero Premium License (worth SGD720)  Complimentary Xero Support  Access to Xero Mobile App  Implementation of Xero  Set up of Company Profile  Integration to InvoiceNow  Chart of Accounts  GST Set-up  Customised Sales Form  Data Migration  Customer/Supplier Database  Balance Sheet for Two Financial Years  Profit and Loss for Two Financial Years  Training and Consultancy by', metadata={'source': 'https://www.aba.com.sg/xero-psg'}),
#  Document(page_content='of Accounts  GST Set-up  Customised Sales Form  Data Migration  Customer/Supplier Database  Balance Sheet for Two Financial Years  Profit and Loss for Two Financial Years  Training and Consultancy by Accountants  Setup with Detailed Migration  $2960  After 50% PSG  12-Month Xero Premium License (worth SGD720)  Complimentary Xero Support  Access to Xero Mobile App  Implementation of Xero  Set up of Company Profile  Integration to InvoiceNow  Chart of Accounts  GST Set-up  Customised Sales Form  Data Migration  Customer/Supplier Database  Balance Sheet for Two Financial Years  Profit and Loss for Two Financial Years  Detailed Migration  (Please contact us to find out more)  Training and Consultancy by Accountants  All our customers are happy with our implementation services by a pool of passionate IT and accounting professionals as we strongly believe we are able to impact your life with the automated accounting system with at least 30% productivity achieved.  Get a Quote  What is Xero?', metadata={'source': 'https://www.aba.com.sg/xero-psg'}),
#  Document(page_content="IT and accounting professionals as we strongly believe we are able to impact your life with the automated accounting system with at least 30% productivity achieved.  Get a Quote  What is Xero?  Simply put, Xero is a cloud-based online accounting software.  What this means for your business is that you will be able to share access to your financial information with your team/accountant/bookkeeper as long as they have internet access.  Gone are the days where your accounting team have to work in silos. Now, your team will be able to work together in the cloud and business owners will be able to get the latest updates on the business' financial health.  Of course, there are more than just the benefit of working together using Xero.  For more details, read our blog post on the benefits of using Cloud Accounting Software like Xero.  Not sure if Xero works for you? Speak to our advisors to find out more.", metadata={'source': 'https://www.aba.com.sg/xero-psg'}),
#  Document(page_content='Jan 4, 20211 min read  Abundant InvoiceNow | PSG XERO/QuickBooks Online Accounting Solutions  Enjoy up to 80% government subsidies with Productivity Solutions Grant (PSG) ! Are you still using PDF invoices? Are you still manually entering invoice data into your accounts?  Source: IMDA, Feb 2021  Move Fast to improve your business with InvoiceNow and save up to 80% with PSG! With InvoiceNow (previously PEPPOL E-invoicing), a nationwide E-invoicing method based on PEPPOL, you can streamline your transactions and focus on the more important tasks. And yes, PEPPOL is international!  Many businesses are already using PDF E-invoices and have benefitted greatly from it. While these invoices are a massive upgrade from paper invoices, what if there is an easier and more effective invoicing method?  Source: IMDA, June 2021  To give you a brief overview of InvoiceNow, you can directly transmit your invoices in a structured digital format from one finance system to another without human', metadata={'source': 'https://www.aba.com.sg/post/invoicenow'}),
#  Document(page_content='method?  Source: IMDA, June 2021  To give you a brief overview of InvoiceNow, you can directly transmit your invoices in a structured digital format from one finance system to another without human intervention as long as both the sender and the recipient are registered on the PEPPOL network. For more, watch InvoiceNow video, courtesy of IMDA.  No more tedious manual data entry of invoices you’ve spent hours on! Reduce human error, improve efficiency while also reducing storage, retrieval and delivery costs.  Call us at 8161 6293, 9776 2954, 9018 1833, click on our website or contact me!  0 views  0 comments  Post not marked as liked  Enjoy up to 80% government subsidies with Productivity Solutions Grant (PSG) ! Are you still using PDF invoices? Are you still manually entering invoice data into your accounts?  Source: IMDA, Feb 2021  Move Fast to improve your business with InvoiceNow and save up to 80% with PSG! With InvoiceNow (previously PEPPOL E-invoicing), a nationwide E-invoicing', metadata={'source': 'https://www.aba.com.sg/post/invoicenow'}),
# ...
#  Document(page_content='issued before 1 January 2023, and a new invoice at 8% GST is to be issued.  On the other hand, if the invoice issuance and goods are delivered before 1 January 2023, the 7% GST rate would apply to the transaction.  Scenario 3: Delivery of Goods/Services before 1 January 2023  If the delivery of goods and services has been performed before 1 January 2023, businesses may elect to charge 7% GST even if the invoice and payment have been received after the rate change.  Business and Operational needs  Aside from understanding the different rates that may apply during the transitional period, businesses also need to assess and plan ahead if the existing Point-of-Sales systems and accounting software can be updated to the new rates.  For GST-inclusive prices on display, these must be updated to reflect the revised rates on 1 Jan 2023. Businesses should therefore be prepared to print or update existing prices or promotional materials, such as price tags, price lists, or websites.  Summary  GST', metadata={'source': 'https://www.aba.com.sg/post/gst-rate-change-with-effect-from-01-january-2023'}),
#  Document(page_content='the revised rates on 1 Jan 2023. Businesses should therefore be prepared to print or update existing prices or promotional materials, such as price tags, price lists, or websites.  Summary  GST is charged at 8% from 1 Jan 2023  Be aware of transitional rules if a transaction straddles the date of the rate change  Ensure that Point-of-sales and accounting systems are ready  Ensure that displayed prices inclusive of GST are up to date  For more information and assistance on accounting and GST matters, do feel free to contact us here.  0 views  0 comments  Post not marked as liked  With the upcoming GST rate increase from 7% to 8% on the horizon, businesses need to take active steps to ensure that staff and operations are ready for the change to come in January 2023. In the article below, we highlight some of the matters that you should be aware of.  Time of Supply and GST  In general, the time of supply rule for GST is that a sale or supply is recognised when a payment is received, or', metadata={'source': 'https://www.aba.com.sg/post/gst-rate-change-with-effect-from-01-january-2023'}),
#  Document(page_content='we highlight some of the matters that you should be aware of.  Time of Supply and GST  In general, the time of supply rule for GST is that a sale or supply is recognised when a payment is received, or when an invoice is issued for goods sold or service performed, whichever is earlier. It follows that from 1 January 2023, any payment received, or invoice issued should be charged at 8% GST.  Transitional Rules affecting rate change  In many cases, there may be time lapses between 1) issuance of the invoice, 2) delivery of goods and services, and 3) payment received from the customer. A transaction that takes place over a period in which the rate change occurs is subjected to transitional rules. Some of the common scenarios that might affect your business include those below:  Scenario 1: Full Payment received before 01 Jan 23  If full payment was received before the rate change on 1 Jan 2023, the supply is subjected to 7% GST. In such cases, the invoice issued after 1 Jan 2023 may', metadata={'source': 'https://www.aba.com.sg/post/gst-rate-change-with-effect-from-01-january-2023'}),
#  Document(page_content='1: Full Payment received before 01 Jan 23  If full payment was received before the rate change on 1 Jan 2023, the supply is subjected to 7% GST. In such cases, the invoice issued after 1 Jan 2023 may reflect GST charged at 7%.  Scenario 2: Invoice issued before 01 Jan 2023  In the event that goods or services have neither been fulfilled, nor payment received for the invoice that was issued before 1 January 2023, the supply will be subjected to 8% GST. A credit note is required to cancel the tax invoice issued before 1 January 2023, and a new invoice at 8% GST is to be issued.  On the other hand, if the invoice issuance and goods are delivered before 1 January 2023, the 7% GST rate would apply to the transaction.  Scenario 3: Delivery of Goods/Services before 1 January 2023  If the delivery of goods and services has been performed before 1 January 2023, businesses may elect to charge 7% GST even if the invoice and payment have been received after the rate change.  Business and', metadata={'source': 'https://www.aba.com.sg/post/gst-rate-change-with-effect-from-01-january-2023'}),
#  Document(page_content='delivery of goods and services has been performed before 1 January 2023, businesses may elect to charge 7% GST even if the invoice and payment have been received after the rate change.  Business and Operational needs  Aside from understanding the different rates that may apply during the transitional period, businesses also need to assess and plan ahead if the existing Point-of-Sales systems and accounting software can be updated to the new rates.  For GST-inclusive prices on display, these must be updated to reflect the revised rates on 1 Jan 2023. Businesses should therefore be prepared to print or update existing prices or promotional materials, such as price tags, price lists, or websites.  Summary  GST is charged at 8% from 1 Jan 2023  Be aware of transitional rules if a transaction straddles the date of the rate change  Ensure that Point-of-sales and accounting systems are ready  Ensure that displayed prices inclusive of GST are up to date  For more information and assistance on', metadata={'source': 'https://www.aba.com.sg/post/gst-rate-change-with-effect-from-01-january-2023'}),
#  Document(page_content='straddles the date of the rate change  Ensure that Point-of-sales and accounting systems are ready  Ensure that displayed prices inclusive of GST are up to date  For more information and assistance on accounting and GST matters, do feel free to contact us here.', metadata={'source': 'https://www.aba.com.sg/post/gst-rate-change-with-effect-from-01-january-2023'}),
#  Document(page_content='Dec 13, 2020  The New Normal for Small and Medium Enterprises (SMEs) | SMEs Go Digital Programme  The year 2020 passed by in a flurry due to the unprecedented circumstances on a scale that the world has never experienced. Due to these...  298 views', metadata={'source': 'https://www.aba.com.sg/blog/categories/smes-go-digital'}),
#  Document(page_content="Business Times Feature: How cloud accounting helped this practice's client make the perfect brew  Nov 24, 2022    3 min  Business Times Feature: How cloud accounting helped this practice's client make the perfect brew  26  2 likes. Post not marked as liked  GST Rate Change with effect from 01 January 2023  Nov 2, 2022    2 min  GST Rate Change with effect from 01 January 2023  600  3 likes. Post not marked as liked  How to contact Quickbooks Online (QBO) Support?  Jan 26, 2022    1 min  How to contact Quickbooks Online (QBO) Support?  222  2 likes. Post not marked as liked", metadata={'source': 'https://www.aba.com.sg/./#comp-kqj5371n'}),
#  Document(page_content='SKILLS FUTURE ENTERPRISE CREDIT  What is SkillsFuture Enterprise Credit (SFEC)?  The SkillsFuture Enterprise Credit (SFEC) encourages employers to invest in enterprise transformation and capabilities of their employees.  Eligible employers will receive a one-off S$10,000 credit to cover up to 90% of out-of-pocket expenses on qualifying costs for supportable initiatives, over and above the support levels of existing schemes.  Tell me more!  SAVE MORE!  Get additional SFEC subsidy for on top of 70% PSG grant!  Package Price*  Less: PSG (50%)  Net Payable after PSG  5,000  2,500  2,500  2,500  You can claim 90% on the out of pocket expenses\xa0if you are eligible for SFEC.  SFEC Utilisation is capped at $7,000 for enterprise transformation programmes (e.g. PSG)  WHO IS ELIGIBLE?  For illustration purposes only  WHO IS ELIGIBLE?  Qualifying period  1 Jan 2021 to 31 Dec 2021  Employed at least 3 Singapore Citizens or Permanent Residents every month over the same qualifying period  Have not', metadata={'source': 'https://www.aba.com.sg/sfec'}),
#  Document(page_content='purposes only  WHO IS ELIGIBLE?  Qualifying period  1 Jan 2021 to 31 Dec 2021  Employed at least 3 Singapore Citizens or Permanent Residents every month over the same qualifying period  Have not been previously qualified\xa0at any of the earlier periods (1 Apr 2019 to 31 Dec 2020)  Are not in default of their SDL contributions during the qualifying period and do not have an inactive ACRA status during qualification.', metadata={'source': 'https://www.aba.com.sg/sfec'}),
#  Document(page_content="Business Times Feature: How cloud accounting helped this practice's client make the perfect brew  Nov 24, 2022    3 min  Business Times Feature: How cloud accounting helped this practice's client make the perfect brew  26  2 likes. Post not marked as liked  GST Rate Change with effect from 01 January 2023  Nov 2, 2022    2 min  GST Rate Change with effect from 01 January 2023  600  3 likes. Post not marked as liked  How to contact Quickbooks Online (QBO) Support?  Jan 26, 2022    1 min  How to contact Quickbooks Online (QBO) Support?  222  2 likes. Post not marked as liked", metadata={'source': 'https://www.aba.com.sg/./#comp-l3vbi3yq'}),
#  Document(page_content='PRIVACY POLICY  Introduction  1. Abundant Accounting \xa0Pte. Ltd. (“Abundant Accounting ” or “we” or “our” or “us”) acts under Singapore’s Personal Data Protection Act 2012 (the “PDPA”). We recognize the importance of the personal data you have provided to us and believe that it is our responsibility to properly manage, protect and process your personal data. Please read this policy to understand what personal data is collected or processed by us, and for what purposes it is used.  2. Personal data is defined in the Personal Data Protection Act as “data, whether true or not, about an individual who can be identified — a) from that data; or b) from that data and other information to which the organisation has or is likely to have access”.  3. The purpose of this policy is to inform you and provide you with an understanding of how we handle, collect, use, disclose and process your personal data. Any changes to this Privacy Policy are effective after posting to this Website. We recommend', metadata={'source': 'https://www.aba.com.sg/privacy-policy'}),
#  Document(page_content='provide you with an understanding of how we handle, collect, use, disclose and process your personal data. Any changes to this Privacy Policy are effective after posting to this Website. We recommend you to check this page from time to time to be aware.  4. By providing your personal data to us, you acknowledge and agree that you have fully read and understood this policy, and consent to the collection, use, processing and disclosure of your personal data as described in this policy.  Collection of Information  1. To process your requests, we collect some personal information, such as:  Full name  Telephone number(s)  Email address  Other personal information required by government agencies  2. We collect most of the personal data for the corporate services’ purposes and disclosure to the government agencies.  3. The data protection provisions in the PDPA (parts III to VI) do not apply to:  Any public agency or organisation in the course of acting on behalf of a public agency in', metadata={'source': 'https://www.aba.com.sg/privacy-policy'}),
#  Document(page_content='to the government agencies.  3. The data protection provisions in the PDPA (parts III to VI) do not apply to:  Any public agency or organisation in the course of acting on behalf of a public agency in relation to the collection, use or disclosure of the personal data. You may wish to refer to the Personal Data Protection (Statutory Bodies) Notification 2013 for the list of specified public agencies.  Business contact information. This refers to an individual’s name, position name or title, business telephone number, business address, business electronic mail address or business fax number and any other similar information about the individual, not provided by the individual solely for his or her personal purposes. You may refer to page 16 under ADVISORY GUIDELINES ON KEY CONCEPTS IN THE PERSONAL DATA PROTECTION ACT  4. All Information provided will be used for the purposes of sharing with ACRA and other Statutory Bodies.  5. Our Website and Application are set up to automatically', metadata={'source': 'https://www.aba.com.sg/privacy-policy'}),
#  Document(page_content='THE PERSONAL DATA PROTECTION ACT  4. All Information provided will be used for the purposes of sharing with ACRA and other Statutory Bodies.  5. Our Website and Application are set up to automatically collect anonymous information about visitors to help us understand our website visitors and their traffic patterns; to know when visitors have accessed our site, which devices our they use for statistical purposes and to improve our service.  6. We will not share any information collected with any non-authorised third parties.  7. We use email, Abundant Accounting\xa0 applications and social media accounts to communicate with clients regarding their requests and services provided.  8. We will occasionally notify you of our new services and corporate special offers via applications or email updates.  9. We will notify you in advance when we collect information for the purposes other than listed above.  Disclosure  1. We disclose your personal and business information only with government', metadata={'source': 'https://www.aba.com.sg/privacy-policy'}),
#  Document(page_content='updates.  9. We will notify you in advance when we collect information for the purposes other than listed above.  Disclosure  1. We disclose your personal and business information only with government bodies for corporate and legal purposes as an organisation in the course of acting on behalf of public agencies.  2. Other than those individuals and entities listed below, your Personal Information will not be revealed by Abundant Accounting\xa0 to any external body, unless Abundant Accounting\xa0 has your permission, or is under either a legal obligation or any other duty to do so. The information provided by you may be disclosed by Abundant Accounting\xa0 to:  regulatory authorities;  lawyers / accountants / auditors or other advisors of Abundant Accounting ;  third party service providers;  any agents acting on our behalf; and  other retailers / business partners / credit information companies / bureaus for the purpose of credit evaluation and debt recovery/collection.  Retention Limitation', metadata={'source': 'https://www.aba.com.sg/privacy-policy'}),
#  Document(page_content='agents acting on our behalf; and  other retailers / business partners / credit information companies / bureaus for the purpose of credit evaluation and debt recovery/collection.  Retention Limitation  1. Section 25 of the PDPA requires us to retain your documents containing personal data as long as we have:  Specific business requirements of services we provide to you;  The obligation under the law to save the data even after our business relationship is over.  Protection  We are committed to ensuring that your information is secure. In order to prevent unauthorized access or disclosure we have put in place suitable physical, electronic and managerial procedures to secure the information.  Openness  Abundant Accounting \xa0is open to sharing information about its data protection practices, policies and complaints processes upon request.', metadata={'source': 'https://www.aba.com.sg/privacy-policy'})]

# %%
# # Define embedding model
# OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# store = Chroma.from_documents(
#     data_split, embeddings, collection_name="aba", persist_directory="db"
# )

# store.persist()
# store = None
# Out:
# Using embedded DuckDB with persistence: data will be stored in: db

# %% [markdown]
# ### Chroma DB persisted

# %%
# Define embedding model
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)
store = Chroma(
    collection_name="aba", persist_directory="db", embedding_function=embeddings
)
store._collection
# Out:
# Using embedded DuckDB with persistence: data will be stored in: db
# Collection(name=aba)

# %%
llm = ChatOpenAI(
    model_name="gpt-3.5-turbo",
    temperature=0,
    openai_api_key=OPENAI_API_KEY,
    max_tokens=512,
)

# %%
sales_template = """
As a customer marketing bot, your goal is to provide accurate and helpful information about Abundant Accounting Pte Ltd.
You should answer user inquiries based on the context provided and avoid making up answers.
If you don't know the answer, simply state that you don't know.
Remember to provide relevant information about how Abundant Accounting Pte Ltd can assist the user through its services, strengths and benefits.

{context}
=========
Question: {question}
"""

SALES_PROMPT = PromptTemplate(
    template=sales_template, input_variables=["context", "question"]
)

sales_qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=store.as_retriever(),
    chain_type_kwargs={"prompt": SALES_PROMPT},
)

# %%
print(sales_qa.run("What is it that the company provides?"))
# Out:
# Abundant Accounting Pte Ltd provides a range of services including corporate advisory, management consultancy, accounting, taxation, corporate secretary, CFO insights, digital accounting system, cloud-based accounting systems, advisory, setting up new business, IT infrastructure and support, cloud-based HR and POS systems, and audit services. Their experienced in-house Chartered Accountants with more than 20 years of experience in MNCs and SMEs provide a holistic and integrated CFO insight to assist businesses in propelling their growth. They also offer advisory services to help businesses optimise their decisions and unleash their hidden potential. Their certified practising management consultants dive deep into analysing business processes and establish a sound, long-term strategy to propel businesses forward.

# %%
print(
    sales_qa.run("I am looking to help my company digitise. How can your company help?")
)
# Out:
# Answer: Abundant Accounting Pte Ltd can help your company digitise by providing IT solutions and transitioning your accounting system into cloud-based accounting. Our professional accountants can assist in reducing manual processes, ease of retrieval for invoices, professional training, and designing reports to facilitate decision making. We can also help enhance revenue growth, control costing, and tax planning/savings. Additionally, we can provide a digital transformation solution that is agile and scalable to accommodate changes in your business model, size, and capabilities. If you require further clarification or assistance, feel free to email us, and we can assign a consultant to follow up with your inquiries.

# %%
print(sales_qa.run("How can I get in touch?"))
# Out:
# To get in touch with Abundant Accounting Pte Ltd, you can visit their office located at 2 Kallang Ave #09-26, CT Hub, Singapore 339407 during their opening hours from Monday to Friday, 9 a.m. to 6 p.m. Alternatively, you can fill out the form on their website for sales inquiries or support. They also offer a live demo session and assistance with PSG Grant and DBS Start Digital.

# %%
print(sales_qa.run("Any phone number I can call?"))
# Out:
# Based on the information provided on the Abundant Accounting Pte Ltd website, you can contact them at the following phone numbers: 8161 6293, 9776 2954, 9018 1833. You can also visit their website or fill out a form to get in touch with their sales or support team. Their office is located at 2 Kallang Ave #09-26, CT Hub, Singapore 339407 and is open from Monday to Friday, 9 a.m. to 6 p.m.
