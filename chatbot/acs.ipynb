# %%
# https://github.com/tomasonjo/blogs/blob/master/neo4jdocs/neo4j_support_bot.ipynb
# %pip install langchain==0.0.142 openai==0.27.4 beautifulsoup4==4.12.2 chromadb==0.3.21

# %%
import os
import dotenv

import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd

from langchain.document_loaders import (
    # GitLoader,
    # YoutubeLoader,
    # DataFrameLoader,
    UnstructuredURLLoader,
)
from langchain.text_splitter import CharacterTextSplitter

import tiktoken

# from langchain.schema import Document
from langchain.embeddings import OpenAIEmbeddings
from langchain.chat_models import ChatOpenAI
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.agents import initialize_agent, Tool

from crawl import crawl, clean, strip_content

# loads .env file with your OPENAI_API_KEY
dotenv.load_dotenv()
# Out:
# True

# %%
# Regex pattern to match a URL
HTTP_URL_PATTERN = r"^http[s]*://.+"

# Define root domain to crawl
DOMAIN = "accountingservices.sg"
FULL_URL = "https://accountingservices.sg/"

# %% [markdown]
# ### Embedding documents for the first time

# %%
seen = crawl(FULL_URL, HTTP_URL_PATTERN)
print(len(seen))
# Out:
# https://accountingservices.sg/
# https://accountingservices.sg/xbrl-filing/
# https://accountingservices.sg/corporate-secretarial/
# https://accountingservices.sg/tax/
# https://accountingservices.sg/2019/05/07/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/accounting/
# https://accountingservices.sg/home/
# https://accountingservices.sg/technological-disruption-in-tax-administration-an-interview-with-mr-peter-green-oecd/
# https://accountingservices.sg/acras-new-free-online-interactive-programme/
# https://accountingservices.sg/iras-recovers-10m-from-tax-avoiding-high-earners/
# https://accountingservices.sg/revision-in-gst-import-relief-for-travellers-with-effect-from-19-february-2019/
# https://accountingservices.sg/financial-reporting-practice-guidance-1-of-2019/
# https://accountingservices.sg/wage-credit-scheme-payouts-for-2019/
# https://accountingservices.sg/more-e-payment-options-for-customers/
# https://accountingservices.sg/paying-taxes-2019_1/
# https://accountingservices.sg/category/news/
# https://accountingservices.sg/2019/06/28/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/file-corporate-income-tax-returns-by-30-nov-15-dec-extended-deadline-for-companies-that-e-file/
# https://accountingservices.sg/2019/11/11/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/author/admin_accountingservices/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/two-company-directors-jailed-for-omitting-more-than-600000-in-company-bonuses-from-income-tax-returns/
# https://accountingservices.sg/category/news/page/3/
# https://accountingservices.sg/2019/01/21/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/category/latest-news/
# https://accountingservices.sg/2019/03/29/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/category/latest-news/page/2/
# https://accountingservices.sg/2019/02/20/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/2019/06/20/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/requirements-of-appointing-a-company-secretary-in-singapore/
# https://accountingservices.sg/enhanced-bizfile-dashboard/
# https://accountingservices.sg/start-up-kit/
# https://accountingservices.sg/choosing-your-business-structure/
# https://accountingservices.sg/category/uncategorized/
# https://accountingservices.sg/2019/08/27/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/2019/08/14/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/2019/08/02/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/upcoming-conference-registration/
# https://accountingservices.sg/start-up-kit-for-sole-proprietorship-and-partnership/
# https://accountingservices.sg/2019/07/11/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/free-online-course-on-starting-a-business/
# https://accountingservices.sg/web-development/
# https://accountingservices.sg/work-passes-and-permits/
# https://accountingservices.sg/iras-annual-report-fy2018-19/
# https://accountingservices.sg/2019/10/30/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/2019/10/06/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/2019/12/03/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/2019/09/05/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/dbs-and-iras-work-towards-singapores-target-to-be-cheque-free-by-2025/
# https://accountingservices.sg/2019/12/11/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/2019/10/17/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/2019/09/15/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/category/news/page/2/
# https://accountingservices.sg/2019/05/21/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/2019/06/11/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/2019/05/29/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/our-professional-bookkeeping-services/
# https://accountingservices.sg/employees-of-jeweller-convicted-for-conspiring-in-gst-tourist-refund-fraud/
# https://accountingservices.sg/weixin://dl/chat?webbpoh
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/transforming-the-taxpaying-experience-connecting-digitally-leveraging-data-intelligently/
# https://accountingservices.sg/web-development
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/reminder-to-hold-annual-general-meeting-agm-and-file-ar-annual-return-on-time/
# https://accountingservices.sg/contact/
# https://accountingservices.sg/2019/04/24/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/2019/04/30/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/2019/05/13/
# HTTP Error 500: Internal Server Error
# https://accountingservices.sg/choose-a-special-uen-sun-for-your-new-business/
# https://accountingservices.sg/news/
# https://accountingservices.sg/payroll/
# https://accountingservices.sg/prices/
# 69

# %%
clean = clean(seen)
print(len(clean))
# Out:
# 69

# %%
urls = list(clean)

# Without headers User-Agent, results in forbidden 403
loader = UnstructuredURLLoader(urls=urls, headers={"User-Agent": "Mozilla/5.0"})
data = loader.load()
print(len(data))
# Out:
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/09/15/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/10/17/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/12/11/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/05/29/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/09/05/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/05/13/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/12/03/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/10/06/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/04/30/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/07/11/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/04/24/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/02/20/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/web-development, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/weixin://dl/chat?webbpoh, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/10/30/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/06/11/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/06/20/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/author/admin_accountingservices/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/11/11/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/08/02/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/08/14/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/05/07/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/01/21/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/03/29/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/08/27/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/05/21/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# The MIME type is 'application/x-empty'. This file type is not currently supported in unstructured.
# Error fetching or processing https://accountingservices.sg/2019/06/28/, exeption: Invalid file. The FileType.UNK file type is not supported in partition.
# 42

# %%
for d in data:
    new_content = strip_content(d.page_content)
    d.page_content = new_content

# %%
# Define text chunk strategy
splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200, separator=" ")
# Split documents into chunks
data_split = splitter.split_documents(data)
print(len(data_split))
# Out:
# 134

# %%
data_split
# Out:
# [Document(page_content='GST Tourist Refund Fraud Six employees of a local jeweller Abiraame Jewellers – Arumugam Chelladurai (aged 48), Kulamani Ganesan (aged 31), Manickavasagam Saravanan (aged 40), Pang Wei Koon (aged 46), Murugesan Saravanan (aged 41) and Shanmugam Sampathkumar (aged 33) – have been convicted in Court for assisting claimants in making fraudulent Goods and Services Tax (GST) tourist refund claims. The six employees faced a total of 80 charges for their involvement in the conspiracy, in which GST tourist refunds amounting to approximately $15,282 were fraudulently claimed. ‘ The Case The case is linked to the five Indian nationals (“claimants”) who were previously arrested and convicted for conspiring to make fraudulent GST refund claims at Changi Airport. As part of their illegal scheme, the claimants would loiter in and around a number of jewellery shops along Serangoon Road, including Abiraame Jewellers’ two shops at 85 and 123 Serangoon Road, for the purpose of obtaining invoices and', metadata={'source': 'https://accountingservices.sg/employees-of-jeweller-convicted-for-conspiring-in-gst-tourist-refund-fraud/'}),
#  Document(page_content='claimants would loiter in and around a number of jewellery shops along Serangoon Road, including Abiraame Jewellers’ two shops at 85 and 123 Serangoon Road, for the purpose of obtaining invoices and jewellery tags from customers of those shops who had made jewellery purchases. The claimants would either approach customers, or be approached by customers or employees of Abiraame Jewellers on behalf of the customers. The claimants would obtain invoices by paying customers for their invoices or by agreeing to help customers bring their jewellery back to India on their behalf. Once a customer agrees to sell or give the invoice, the claimant would give his passport and embarkation card (white card) to an employee of Abiraame Jewellers to apply for a GST refund under the claimant’s passport number. The employees would enter the details of the claimant and the jewellery purchased into the electronic Tourist Refund Scheme (eTRS) system, and print an eTRS refund ticket for the claimant. The', metadata={'source': 'https://accountingservices.sg/employees-of-jeweller-convicted-for-conspiring-in-gst-tourist-refund-fraud/'}),
#  Document(page_content='number. The employees would enter the details of the claimant and the jewellery purchased into the electronic Tourist Refund Scheme (eTRS) system, and print an eTRS refund ticket for the claimant. The employees did this despite knowing that the claimants were not eligible for the refunds as they were not the actual purchasers of the jewellery listed on the eTRS refund tickets. Abuse of the GST Tourist Refund Scheme (TRS) The TRS is available only to bona fide tourists for the claiming of GST refunds on goods they have purchased and brought out of Singapore. Permanent Residents, as well as foreigners who have been employed in Singapore in the past six months before the date of purchase, are not eligible for GST refunds under the TRS. It is an offence for a person to obtain GST refunds if the person does not meet the TRS qualifying criteria and conditions. It is also an offence for an individual to assist another person in obtaining fraudulent eTRS refunds, such as by selling one’s', metadata={'source': 'https://accountingservices.sg/employees-of-jeweller-convicted-for-conspiring-in-gst-tourist-refund-fraud/'}),
#  Document(page_content='if the person does not meet the TRS qualifying criteria and conditions. It is also an offence for an individual to assist another person in obtaining fraudulent eTRS refunds, such as by selling one’s receipt or invoice to support the claim. IRAS will not hesitate to take stern enforcement actions against any individual who with willful intent make a false GST refund claim or assist any other person to make false claims. IRAS will also not hesitate to take firm action against retailers who are complicit or negligent in the issuing of eTRS tickets leading to the abuse of the Tourist Refund Scheme. See also: Penalty for failing to register for GST Post navigation PreviousPrevious post:Enhanced BizFile+ Dashboard NextNext post:Start-Up Kit for Sole Proprietorship and Partnership', metadata={'source': 'https://accountingservices.sg/employees-of-jeweller-convicted-for-conspiring-in-gst-tourist-refund-fraud/'}),
#  Document(page_content='Choose a Special UEN (SUN) for your New Business May 13, 2019 Special UEN (SUN): Choose Your Preferred UEN A Unique Entity Number (UEN) is an identification number that is generated for a business entity, following successful incorporation/registration with ACRA. All business… Transforming the Taxpaying Experience – Connecting Digitally, Leveraging Data Intelligently May 7, 2019 Transforming the Taxpaying Experience – Connecting Digitally, Leveraging Data Intelligently 96% of taxpayers submitted their individual income tax returns by 18 Apr 2019. The Inland Revenue Authority of Singapore (IRAS)… Reminder to Hold Annual General Meeting (AGM) and File AR (Annual Return) on Time April 30, 2019 Changes on statutory requirements for AGM and filing of AR Companies due to hold AGMs in the coming months should take note of changes to the timelines for holding AGMs… Technological Disruption in Tax Administration – An Interview with Mr Peter Green, OECD April 24, 2019 Technological Disruption in', metadata={'source': 'https://accountingservices.sg/'}),
#  Document(page_content='months should take note of changes to the timelines for holding AGMs… Technological Disruption in Tax Administration – An Interview with Mr Peter Green, OECD April 24, 2019 Technological Disruption in Tax Administration – An Interview with Mr Peter Green, OECD Singapore hosted the 3rd OECD FTA E-Services and Digital Delivery Workshop from 24 April to 26 April…', metadata={'source': 'https://accountingservices.sg/'}),
#  Document(page_content='Financial Reporting Practice Guidance 1 of 2019 To assist directors in reviewing their company’s upcoming financial statements, ACRA has issued Practice Guidance No. 1 of 2019 which highlights five financial reporting areas that may require more attention by directors before approving the companies’ FY2018 Financial Statements. The key area for this year is the adoption of significant new accounting standards on revenue and financial instruments. Specific changes that may have more widespread impact were highlighted for directors’ consideration. Other areas include impairment assessment and valuation, major transactions, statement of cash flows and disclosures of significant judgements and estimates. The Practice Guidance is available for download here. Post navigation PreviousPrevious post:Revision in GST Import Relief for Travellers with effect from 19 February 2019 NextNext post:Wage Credit Scheme Payouts for 2019', metadata={'source': 'https://accountingservices.sg/financial-reporting-practice-guidance-1-of-2019/'}),
#  Document(page_content='New business start up implies increased need for book keeping services. As a businessperson, you would be conversant of the necessity of accounting services. Small businesses do not look forward to wasting time and energy on complex and extensive paper work. Therefore, we offer them our reliable and reputed bookkeeping Singapore services to assist them. Our company would be your one stop shop ranging from company registration, incorporation, book keeping and accounting needs. We have been providing to the needs of different kinds of companies in Singapore for a significant length of time. Our experience in the arena would help you grow and succeed in the right manner possible. Our reliable and reputed book keeping services Our reliable and reputed book keeping services would entail reviewing existing bookkeeping systems to meet the needs of the customers. We would input new information and run financial management statements monthly, quarterly or yearly. Our experts in bookkeeping', metadata={'source': 'https://accountingservices.sg/our-professional-bookkeeping-services/'}),
#  Document(page_content='existing bookkeeping systems to meet the needs of the customers. We would input new information and run financial management statements monthly, quarterly or yearly. Our experts in bookkeeping would prepare payroll records of federal and state withholding reports.Our services would also be inclusive of creation of management reports, invoice, assistance in tax preparation and various office data management tasks. Our services would also cater to your word processing, bulk mailing and data entry needs. Our experts would handle your companies need for coordinating and handling accounts, paying salaries, checkbooks and balancing ledgers. We would organize your entire financial information needed for loan proposals, business plans, cash-flow statements and more. The list is endless. Overall, we would be handling your entire financial needs in the right manner. How do our bookkeeping services help you enhance business? Our bookkeeping services are popular with start up and established', metadata={'source': 'https://accountingservices.sg/our-professional-bookkeeping-services/'}),
#  Document(page_content='we would be handling your entire financial needs in the right manner. How do our bookkeeping services help you enhance business? Our bookkeeping services are popular with start up and established businesses. We would offload all your arduous tasks of managing and maintaining financial records. We would help you not to lose access to several important details of your business. The traditional bookkeepers would need their records to be submitted to them. However, that is not the case with our professional bookkeeping services. Our web based filing systems would enable you to access the accounts round the clock. We would file and maintain your bills, invoices and expenses. We would maintain the financial records up to date for your convenience of viewing. We help you succeed in business Going by our motto, we will rise with you. We would provide you with best bookkeeping services to help you stay focused on your needs to enhance the business further. If you are ready to start a company,', metadata={'source': 'https://accountingservices.sg/our-professional-bookkeeping-services/'}),
#  Document(page_content='by our motto, we will rise with you. We would provide you with best bookkeeping services to help you stay focused on your needs to enhance the business further. If you are ready to start a company, call us today! Post navigation NextNext post:Requirements of Appointing a Company Secretary in Singapore', metadata={'source': 'https://accountingservices.sg/our-professional-bookkeeping-services/'}),
#  Document(page_content='Free online course on starting a business News By admin_accountingservices June 11, 2019 Work passes and permits News By admin_accountingservices May 29, 2019 Penalty for failing to register for GST News By admin_accountingservices May 21, 2019 Choose a Special UEN (SUN) for your New Business News, Latest News By admin_accountingservices May 13, 2019 Transforming the Taxpaying Experience – Connecting Digitally, Leveraging Data Intelligently News, Latest News By admin_accountingservices May 7, 2019 Reminder to Hold Annual General Meeting (AGM) and File AR (Annual Return) on Time News, Latest News By admin_accountingservices April 30, 2019 Technological Disruption in Tax Administration – An Interview with Mr Peter Green, OECD News, Latest News By admin_accountingservices April 24, 2019 ACRA’s new free online interactive programme News, Latest News By admin_accountingservices March 29, 2019 Iras recovers $10m from tax-avoiding high earners News, Latest News By admin_accountingservices', metadata={'source': 'https://accountingservices.sg/category/news/page/2/'}),
#  Document(page_content='new free online interactive programme News, Latest News By admin_accountingservices March 29, 2019 Iras recovers $10m from tax-avoiding high earners News, Latest News By admin_accountingservices February 20, 2019 Revision in GST Import Relief for Travellers with effect from 19 February 2019 News, Latest News By admin_accountingservices February 20, 2019', metadata={'source': 'https://accountingservices.sg/category/news/page/2/'}),
#  Document(page_content='Skip to content Home Profile ServicesAccounting Payroll Tax XBRL Filing Corporate Secretarial OthersWeb Development Prices News Contact +65 9362 3460 info@accountingservices.sg +65 9362 3460 +65 9362 3460 Home Profile ServicesAccounting Payroll Tax XBRL Filing Corporate Secretarial OthersWeb Development Prices News Contact Prices You are here: Home Prices Accounting Services Package Fees in Singapore Accounting Services, a premier firm in Singapore, prides itself on offering end-to-end corporate accounting services at extremely cost-effective package fees. Learn more about them and our services in Singapore by reading on! Package #1 From S$350* Compilation report + Corporate Tax services Annual Compilation Report Computation of Estimated Chargeable Income (“ECI”) Tax computation and supporting schedules Completion of Form C/Form C-S & Submission to the Comptroller of Income Tax Package #2 From S$500* Bookkeeping + Compilation report + Corporate Tax services Monthly/Quarterly/Yearly', metadata={'source': 'https://accountingservices.sg/prices/'}),
#  Document(page_content='schedules Completion of Form C/Form C-S & Submission to the Comptroller of Income Tax Package #2 From S$500* Bookkeeping + Compilation report + Corporate Tax services Monthly/Quarterly/Yearly management accounts Annual Compilation Report Computation of Estimated Chargeable Income (“ECI”) Tax computation and supporting schedules Completion of Form C/Form C-S & Submission to the Comptroller of Income Tax Package #3 From S$900* Bookkeeping + Compilation report + GST and Corporate Tax services Monthly/Quarterly/Yearly management accounts Annual Compilation Report Computation of Estimated Chargeable Income (“ECI”) Computation and submission of GST Form 5 tothe Comptroller of GST Department Corporate Tax computation and supporting schedules Completion of Form C/Form C-S &Submission to the Comptroller of Income Tax Package #4 From S$1,200* Incorporation + Accounting & Tax Services + Corporate Secretarial Services Incorporation of Singapore private limited company Preparation of company', metadata={'source': 'https://accountingservices.sg/prices/'}),
#  Document(page_content="Comptroller of Income Tax Package #4 From S$1,200* Incorporation + Accounting & Tax Services + Corporate Secretarial Services Incorporation of Singapore private limited company Preparation of company Startup Kit Nominee corporate secretary services Monthly/Quarterly/Yearly management accounts Annual Compilation Report Annual General Meeting documentation and filing Computation of Estimated Chargeable Income (“ECI”) Corporate Tax computation and supporting schedules Completion of Form C/Form C-S & Submission to the Comptroller of Income Tax Please note that the estimated fees illustrated are indicative in nature. Our quotes will be adjusting accordingly on the basis of the level of transactions: Low transaction volume: 1 – 100 Medium transaction volume: 101 – 300 High transaction volume: 301 and above None of the above satisfies your needs? Here's more for your consideration: GST Package From S$500* Application for GST registration/Application for exemption from GST registration", metadata={'source': 'https://accountingservices.sg/prices/'}),
#  Document(page_content="301 and above None of the above satisfies your needs? Here's more for your consideration: GST Package From S$500* Application for GST registration/Application for exemption from GST registration Preparation of quarterly GST computation Submission of GST Form 5 to the Comptroller of GST Department Handling queries raised by tax officers GST Registration . . . You are liable for GST registration if: Your taxable turnover at the end of the calendar quarter (i.e. end Mar, Jun, Sep or Dec) and the past three quarters is more than $1 million. (“Retrospective View”) You can reasonably expect your taxable turnover in the next 12 months to be more than $1 million e.g. signing of a sales contract or business agreement. (“Prospective View”) Please note that the estimated fees illustrated are indicative in nature. Our quotes will be adjusting accordingly based on the level of transactions. Payroll Package From S$188* Calculate employees’ salary based on their overtime, bonus, commission,", metadata={'source': 'https://accountingservices.sg/prices/'}),
#  Document(page_content="indicative in nature. Our quotes will be adjusting accordingly based on the level of transactions. Payroll Package From S$188* Calculate employees’ salary based on their overtime, bonus, commission, allowances, claims and deductions when you leverage our accounting services packages CPF Submission which includes SDL/FWL, and donation to relevant organizations in Singapore Provide pay slip Preparation of year-end income and tax forms (IR8A) Process claims on expenses Save Costs . . . Rather than having to incur monthly salary payment for your in-house payroll executive, isn’t it better to outsource your payroll function with significantly lower direct costs charged only for a month end task? ? That’s where our corporate accounting services package in Singapore comes in! Should you have any questions about our corporate accounting services packages in Singapore, leave us a message!We're here to ensure that your business requirements are met, so tell us more about your company and we'll", metadata={'source': 'https://accountingservices.sg/prices/'}),
#  Document(page_content="questions about our corporate accounting services packages in Singapore, leave us a message!We're here to ensure that your business requirements are met, so tell us more about your company and we'll handle the rest for you. Save your costs and get in touch today! Minimum 3 employees Should you have any questions about our corporate accounting services packages in Singapore, leave us a message! We're here to ensure that your business requirements are met, so tell us more about your company and we'll handle the rest for you. Save your costs and get in touch today! Accounting Services \u200bTel: +65 9362 3460 Email: info@accountingservices.sg WHAT WE OFFER Accounting Payroll Tax XBRL Filing Corporate Secretarial QUICK LINKS Home About Us News Prices Contact Copyright © 2019 Accounting Services. All Rights Reserved. Go to Top", metadata={'source': 'https://accountingservices.sg/prices/'}),
#  Document(page_content='Skip to content Home Profile ServicesAccounting Payroll Tax XBRL Filing Corporate Secretarial OthersWeb Development Prices News Contact +65 9362 3460 info@accountingservices.sg +65 9362 3460 +65 9362 3460 Home Profile ServicesAccounting Payroll Tax XBRL Filing Corporate Secretarial OthersWeb Development Prices News Contact Payroll You are here: Home Payroll Payroll Services Payroll function have always been a tedious and time-consuming process whereby it jeopardize the productivity of an organisation. By outsourcing the payroll function, it put mind at ease for the organization so that it can concentrate on the revenue generating activities. Why pay extra headcount to do the payroll needs when we can provide the services at an affordable rate! At Skye, we process payroll for employees in accordance to local statutory requirements on the scheduled time requested. Services Provided: Keep and maintain employees’ information Calculate employees’ salary based on their overtime, bonus,', metadata={'source': 'https://accountingservices.sg/payroll/'}),
#  Document(page_content="in accordance to local statutory requirements on the scheduled time requested. Services Provided: Keep and maintain employees’ information Calculate employees’ salary based on their overtime, bonus, commission, allowances, claims and deductions Calculate the late payment upon resignation or termination of employees CPF Submission which includes SDL/FWL, and donation to relevant organisations Process the necessary claims from the authorities (e.g. NS Men Make-up Pay, Maternity, Paternity and Child Care leave claims) Filing of tax clearance for foreign workers (IR21) Preparation of year-end income and tax forms (IR8A)Process claims on expenses Prepare Letter of Appointment for Employees Provide payslip Prices... One time off set-up : $100 Basic Payroll Services : $10 / employee There will be additional charges for special payroll arrangement. Want to enquire more about our Payroll services? Send us a message, and we'll get in touch very soon! Accounting Services \u200bTel: +65 9362 3460", metadata={'source': 'https://accountingservices.sg/payroll/'}),
#  Document(page_content="be additional charges for special payroll arrangement. Want to enquire more about our Payroll services? Send us a message, and we'll get in touch very soon! Accounting Services \u200bTel: +65 9362 3460 Email: info@accountingservices.sg WHAT WE OFFER Accounting Payroll Tax XBRL Filing Corporate Secretarial QUICK LINKS Home About Us News Prices Contact Copyright © 2019 Accounting Services. All Rights Reserved. Go to Top", metadata={'source': 'https://accountingservices.sg/payroll/'}),
#  Document(page_content='Wage Credit Scheme Payouts for 2019 Employers are reminded to make CPF contributions for employees by 14 January 2019 to receive Wage Credit Scheme payouts Employers of eligible Singaporean employees are reminded to make the full CPF contributions for these employees by 14 January 2019 in order to receive the sixth tranche of Wage Credit Scheme (WCS) payouts in March 2019. To qualify for the sixth tranche of the WCS payouts, employers must fulfil the following conditions: Have given Singaporean employees a gross monthly wage increase of at least $50 in 2018 and/or have sustained the gross monthly wage increase (at least $50) previously given to employees in 2017; and Have paid the employees’ mandatory CPF contributions on 2018 wages to the CPF Board by 14 January 2019. Employers do not need to apply to receive the WCS payouts. Eligible employers will receive letters from the Inland Revenue Authority of Singapore (IRAS) by March 2019 informing them of the amount of WCS payouts to be', metadata={'source': 'https://accountingservices.sg/wage-credit-scheme-payouts-for-2019/'}),
#  Document(page_content='need to apply to receive the WCS payouts. Eligible employers will receive letters from the Inland Revenue Authority of Singapore (IRAS) by March 2019 informing them of the amount of WCS payouts to be received. The payouts will be credited directly into their company’s GIRO bank account used for Income Tax and GST, or their bank account that is registered with PayNow Corporate. Employers who are not on these direct crediting modes are encouraged to sign up for PayNow Corporate by 14 January 2019. Post navigation PreviousPrevious post:Financial Reporting Practice Guidance 1 of 2019 NextNext post:More e-payment options for customers', metadata={'source': 'https://accountingservices.sg/wage-credit-scheme-payouts-for-2019/'}),
#  Document(page_content='Our Professional Bookkeeping Services – Your Best Solution Requirements of Appointing a Company Secretary in Singapore Two company directors jailed for omitting more than $600,000 in company bonuses from income tax returns File Corporate Income Tax Returns by 30 Nov, 15 Dec Extended Deadline for Companies that e-File DBS and IRAS work towards Singapore’s target to be cheque-free by 2025 IRAS Annual Report FY2018/19 Enhanced BizFile+ Dashboard Employees of Jeweller Convicted for Conspiring in GST Tourist Refund Fraud Start-Up Kit for Sole Proprietorship and Partnership Upcoming Conference 2019 Address Registered for your Company Choosing Your Business Structure Start-Up Kit for New Companies Register Your Business With ACRA Free online course on starting a business Work passes and permits Penalty for failing to register for GST Choose a Special UEN (SUN) for your New Business Transforming the Taxpaying Experience – Connecting Digitally, Leveraging Data Intelligently Reminder to Hold', metadata={'source': 'https://accountingservices.sg/news/'}),
#  Document(page_content='Penalty for failing to register for GST Choose a Special UEN (SUN) for your New Business Transforming the Taxpaying Experience – Connecting Digitally, Leveraging Data Intelligently Reminder to Hold Annual General Meeting (AGM) and File AR (Annual Return) on Time Technological Disruption in Tax Administration – An Interview with Mr Peter Green, OECD ACRA’s new free online interactive programme Iras recovers $10m from tax-avoiding high earners Revision in GST Import Relief for Travellers with effect from 19 February 2019 Financial Reporting Practice Guidance 1 of 2019 Wage Credit Scheme Payouts for 2019 More e-payment options for customers Budget 2019 – Overview of Tax Changes', metadata={'source': 'https://accountingservices.sg/news/'}),
#  Document(page_content='Special UEN (SUN): Choose Your Preferred UEN A Unique Entity Number (UEN) is an identification number that is generated for a business entity, following successful incorporation/registration with ACRA. All business entities need to use the UEN when transacting with government agencies. This UEN is issued free of charge to business entities. Entity owners can choose, at a fee, a preferred UEN from a list of reserved UENs during entity incorporation/registration or conversion. This preferred UEN is known as Special UEN (SUN). Those who do not wish to apply for a SUN will continue to be issued with a free system-generated UEN. SUN enables entity owners to more easily identify with and remember their own UEN when transacting with government agencies. Types of SUN Entity owners who would like to apply for the SUN service can choose their preferred UENs through two tiers as follows: Tier 1 Fee: S$3,000 per SUN SUN is defined as number with consecutive same number, or any number combination', metadata={'source': 'https://accountingservices.sg/choose-a-special-uen-sun-for-your-new-business/'}),
#  Document(page_content='to apply for the SUN service can choose their preferred UENs through two tiers as follows: Tier 1 Fee: S$3,000 per SUN SUN is defined as number with consecutive same number, or any number combination involving the number ‘8’ Tier 2 Fee: S$1,000 per SUN SUN is defined as number with repetitive pattern (excluding the number ‘8’), or ending with triple identical number (such as ‘222’, ‘666’, ‘777’) Examples of SUN under each tier: Consecutive same number 201888888A 53499999V T18LL7777F T18LP2222J T18PF1111P Any number combination involving ‘8’ 201800800K 53480008L T18LL8000O T18LP0008H T18PF8800X Repetitive Pattern (excluding ‘8’) 201812121R 53410101G T18LL7070F T18LP3535J T18PF1010R Ending with triple identical number 201801777W 53415666P T18LL1222N T18LP5222S T18PF1666M Not sure how to apply the Special UEN for your new company? We are here to assist with the incorporation service too! Find out more about our package fees here. Post navigation PreviousPrevious post:Penalty for failing', metadata={'source': 'https://accountingservices.sg/choose-a-special-uen-sun-for-your-new-business/'}),
#  Document(page_content='the Special UEN for your new company? We are here to assist with the incorporation service too! Find out more about our package fees here. Post navigation PreviousPrevious post:Penalty for failing to register for GST NextNext post:Transforming the Taxpaying Experience – Connecting Digitally, Leveraging Data Intelligently', metadata={'source': 'https://accountingservices.sg/choose-a-special-uen-sun-for-your-new-business/'}),
#  Document(page_content='DBS and IRAS work towards Singapore’s target to be cheque-free by 2025 Collaboration involves digitalising tax payments and collections via PayNow for a start In line with Singapore’s Smart Nation agenda, DBS Bank is collaborating with the Inland Revenue Authority of Singapore (IRAS) to digitalise tax payouts and collections via PayNow to encourage more businesses to go cheque-free. IRAS first introduced PayNow as an option for businesses to receive Wage Credit Scheme[1] (WCS) payouts in March, resulting in a 20 per cent reduction in cheque volumes to-date. Before the implementation of PayNow, about half of WCS-eligible businesses, many of which are small and medium-sized enterprises (SMEs), chose to receive their payouts via cheques. Ms Ang Sor Tjing, Director of IRAS’ Revenue and Payment Management Branch said, “Implementing PayNow for the disbursement of the scheme’s payouts helps encourage businesses, many of which comprise SMEs, to go chequeless and transition towards digital', metadata={'source': 'https://accountingservices.sg/dbs-and-iras-work-towards-singapores-target-to-be-cheque-free-by-2025/'}),
#  Document(page_content='Management Branch said, “Implementing PayNow for the disbursement of the scheme’s payouts helps encourage businesses, many of which comprise SMEs, to go chequeless and transition towards digital payments. As part of IRAS’ digitalisation drive, we are also working with DBS to expand the use of PayNow to more services for the convenience of businesses and individuals.” Mr Raof Latiff, Group Head of Digital, Institutional Banking Group, DBS Bank said, “Acceptance of digital transactions among individuals in Singapore has been well established. To bring Singapore’s digital agenda to fruition, it is critical to encourage SMEs to get on board the digital payments train as they represent 99 per cent of businesses locally. Partnering with statutory boards like IRAS is one of the key ways to encourage this shift, with them leading the way by digitalising payments and collections channels across their suite of services.” For the next phase, both parties are working together to leverage DBS’ APIs', metadata={'source': 'https://accountingservices.sg/dbs-and-iras-work-towards-singapores-target-to-be-cheque-free-by-2025/'}),
#  Document(page_content='this shift, with them leading the way by digitalising payments and collections channels across their suite of services.” For the next phase, both parties are working together to leverage DBS’ APIs (application programming interface) to digitalise IRAS’ stamp duty services. Currently, most taxpayers tend to pay for conveyancing stamp duty[2] via cheques and have to wait several days for the cheque to be cleared before a stamp duty certificate is issued. However, with DBS’ Direct Debit Authorisation (DDA) API, taxpayers can set up a GIRO account online, and make payment for their stamp duty and receive a stamp certificate through IRAS’ e-Stamping Portal instantly. In addition, with a transfer limit of SGD200,000 per transaction, the DBS DDA solution also enables IRAS to digitalise payments for the majority of conveyancing stamp duty transactions. This new DDA e-payment option for conveyancing stamp duty will be launched in November, and more details can be found on the IRAS website', metadata={'source': 'https://accountingservices.sg/dbs-and-iras-work-towards-singapores-target-to-be-cheque-free-by-2025/'}),
#  Document(page_content='for the majority of conveyancing stamp duty transactions. This new DDA e-payment option for conveyancing stamp duty will be launched in November, and more details can be found on the IRAS website closer to the launch date. “Besides stamp duty payments, with cashless payments gaining momentum in Singapore, taxpayers are encouraged to use cashless or electronic payment modes such as GIRO and online banking to fulfil their other tax obligations,” said Ms Ang. DBS continues to see traction from SMEs in the adoption of PayNow DBS currently banks more than one in two SMEs in Singapore and continues to see healthy interest from the segment to digitalise their businesses. Since PayNow was launched to corporates in August last year, DBS has seen a steady increase in SMEs adopting the digital payment collections solution, with the bank holding close to 40 per cent of the market share by registrations to date. From a transactions perspective, DBS’ corporate clients contribute to more than half of', metadata={'source': 'https://accountingservices.sg/dbs-and-iras-work-towards-singapores-target-to-be-cheque-free-by-2025/'}),
#  Document(page_content='collections solution, with the bank holding close to 40 per cent of the market share by registrations to date. From a transactions perspective, DBS’ corporate clients contribute to more than half of PayNow Corporate receipts in Singapore, with volumes from the bank’s SME customers growing threefold to date. This was mainly driven by healthy take-up of the bank’s PayNow-integrated QR payment solution, DBS MAX, which led to a doubling in digital payment and collection transactions by SMEs since the solution was launched in November 2018. “Singapore has continued to show steady progress in the adoption of digital payments on the back of the government’s continuous push to become a Smart Nation. However, in order to fulfil Singapore’s ambition to go chequeless by 2025, we need to continue to innovate and explore new ways to help ease businesses, especially SMEs, into the digital future, while providing them the support they need to face the challenges ahead,” said Mr Latiff. To this end,', metadata={'source': 'https://accountingservices.sg/dbs-and-iras-work-towards-singapores-target-to-be-cheque-free-by-2025/'}),
#  Document(page_content='innovate and explore new ways to help ease businesses, especially SMEs, into the digital future, while providing them the support they need to face the challenges ahead,” said Mr Latiff. To this end, DBS has invested more than 100 hours this year in customer workshops to educate business owners on the benefits of digital payment solutions such as DBS MAX, and targets to ramp up the adoption of DBS MAX among its SME clients by five times by end 2020. [1] https://www.iras.gov.sg/IRASHome/Schemes/Businesses/Wage-Credit-Scheme–WCS-/ [2] Conveyancing stamp duty refers to taxes relating to the purchase of a property Post navigation PreviousPrevious post:File Corporate Income Tax Returns by 30 Nov, 15 Dec Extended Deadline for Companies that e-File NextNext post:IRAS Annual Report FY2018/19', metadata={'source': 'https://accountingservices.sg/dbs-and-iras-work-towards-singapores-target-to-be-cheque-free-by-2025/'}),
#  Document(page_content='Revision in GST Import Relief for Travellers with effect from 19 February 2019 The GST import relief for travellers (Singapore Citizens, Singapore Permanent Residents and tourists) will be tightened for travellers arriving in Singapore, starting from 12.00am on 19 February 2019. This was announced by the Minister for Finance in the Budget 2019 Statement. Travellers who spend less than 48 hours outside Singapore will get GST relief for the first S$100 (instead of S$150 currently) of the value of goods. Travellers who spend at least 48 hours outside Singapore will get GST relief for the first S$500 (instead of $600 currently) of the value of goods. The revision in GST import relief limits is made to ensure that our tax system continues to remain resilient, amidst rising international travel. GST is a tax on domestic consumption of goods and services supplied in and imported into Singapore. Hence, goods brought into Singapore are subject to GST. The GST import relief seeks to balance', metadata={'source': 'https://accountingservices.sg/revision-in-gst-import-relief-for-travellers-with-effect-from-19-february-2019/'}),
#  Document(page_content='GST is a tax on domestic consumption of goods and services supplied in and imported into Singapore. Hence, goods brought into Singapore are subject to GST. The GST import relief seeks to balance between collecting GST revenue and facilitating customs clearance at the borders. On arrival in Singapore, travellers carrying goods with values exceeding their GST import relief are required to declare the goods and make payment for the required GST. They are advised to keep and produce the invoices or receipts of their purchases for computation and verification of the tax payable. Post navigation PreviousPrevious post:Iras recovers $10m from tax-avoiding high earners NextNext post:Financial Reporting Practice Guidance 1 of 2019', metadata={'source': 'https://accountingservices.sg/revision-in-gst-import-relief-for-travellers-with-effect-from-19-february-2019/'}),
#  Document(page_content='Singapore Budget 2019 Summary The following tax changes were announced by the Minister for Finance, Mr. Heng Swee Keat, in his Budget Statement for the Financial Year 2019, which was delivered in Parliament on Monday, 18 Feb 2019. For Individuals Personal Income Tax Rebate for resident individual taxpayers for Year of Assessment (“YA”) 2019 As part of the Bicentennial Bonus, a Personal Income Tax Rebate of 50% of tax payable will be granted to all tax resident individuals for YA 2019 (i.e. for income earned in 2018). The rebate will be capped at $200 per taxpayer. Allow resident individual taxpayers to claim Grandparent Caregiver Relief in respect of a handicapped and unmarried dependent child, regardless of the child’s age To provide greater support and recognition to working mothers with handicapped and unmarried dependent children, taxpayers will be allowed to claim Grandparent Caregiver Relief in respect of a handicapped and unmarried dependent child, regardless of the child’s age,', metadata={'source': 'https://accountingservices.sg/paying-taxes-2019_1/'}),
#  Document(page_content='handicapped and unmarried dependent children, taxpayers will be allowed to claim Grandparent Caregiver Relief in respect of a handicapped and unmarried dependent child, regardless of the child’s age, if they have met all other conditions. This will take effect from YA 2020 (i.e. for income earned in 2019). Lapse the Not Ordinarily Resident (“NOR”) scheme The NOR scheme will lapse after YA 2020. The last such NOR status will be granted for YA 2020 and expire in YA 2024. Individuals who have been accorded the NOR status will continue to be granted NOR tax concessions until their NOR status expires, if they continue to meet the conditions of the concessions. For All Businesses Extend the Writing Down Allowance (“WDA”) for acquisition of qualifying Intellectual Property Rights (“IPRs”) under section 19B of the Income Tax Act (“ITA”) In recognition that IPRs are important creators of value in a knowledge-based economy, the WDA under section 19B will be extended to cover capital expenditure', metadata={'source': 'https://accountingservices.sg/paying-taxes-2019_1/'}),
#  Document(page_content='section 19B of the Income Tax Act (“ITA”) In recognition that IPRs are important creators of value in a knowledge-based economy, the WDA under section 19B will be extended to cover capital expenditure incurred in respect of qualifying IPRs acquired on or before the last day of the basis period for YA 2025. Extend the income tax concessions for Singapore-listed Real Estate Investment Trusts (“S-REITs”) To continue to promote the listing of REITs in Singapore and to strengthen Singapore’s position as a REITs hub in Asia, the existing tax concessions for S-REITs will be extended till 31 December 2025. The sunset clause for the tax exemption on S-REITs distributions received by individuals will be removed. All other conditions for the income tax concessions remain the same. MAS will provide further details of the change by May 2019. Extend the income tax concessions for Singapore-listed Real Estate Investment Trusts Exchange-Traded Funds (“REITs ETFs”) The existing tax treatment accorded', metadata={'source': 'https://accountingservices.sg/paying-taxes-2019_1/'}),
#  Document(page_content='further details of the change by May 2019. Extend the income tax concessions for Singapore-listed Real Estate Investment Trusts Exchange-Traded Funds (“REITs ETFs”) The existing tax treatment accorded to REITs ETFs will be extended till 31 December 2025. The sunset clause will be removed for the tax exemption on REITs ETFs distributions received by individuals. All other conditions for the income tax concessions remain the same. MAS will provide further details of the change by May 2019. Lapsing of Designated Unit Trust (“DUT”) scheme after 31 March 2019 Existing DUTs will continue to receive the tax deferral benefits under the DUT scheme, on and after 1 April 2019, if they continue to meet all the conditions. Lapsing of Approved Unit Trust (“AUT”) scheme after 18 February 2019 Existing AUTs will continue to receive the tax concession under the AUT scheme for a period of five years from YA 2020 to YA 2024. This will allow existing AUTs sufficient time to transit to alternative tax', metadata={'source': 'https://accountingservices.sg/paying-taxes-2019_1/'}),
#  Document(page_content='AUTs will continue to receive the tax concession under the AUT scheme for a period of five years from YA 2020 to YA 2024. This will allow existing AUTs sufficient time to transit to alternative tax incentive schemes, where relevant. Goods and Services Tax Tighten the GST Import Relief for Travellers Travellers who spend less than 48 hours outside Singapore will get GST import relief for the first $100 (instead of $150 currently) of the value of goods bought overseas. Travellers who spend at least 48 hours outside Singapore will get GST import relief for the first $500 (instead of $600 currently) of the value of goods bought overseas. This will take effect for travelers arriving in Singapore from 12.00am, 19 February 2019. Extend the GST remission for S-REITs and Singapore-listed Registered Business Trusts (“RBTs”) in the infrastructure business, ship leasing and aircraft leasing sectors To continue facilitating the listing of S-REITs and RBTs in the infrastructure business, ship', metadata={'source': 'https://accountingservices.sg/paying-taxes-2019_1/'}),
#  Document(page_content='Business Trusts (“RBTs”) in the infrastructure business, ship leasing and aircraft leasing sectors To continue facilitating the listing of S-REITs and RBTs in the infrastructure business, ship leasing and aircraft leasing sectors, the existing GST remission will be extended till 31 December 2025. All conditions for the GST remission remain the same. MAS will provide further details of the change by May 2019. Property Tax Lapse the Property Tax (Tourist Projects) Order Schemes are reviewed regularly to ensure relevance. The Property Tax (Tourist Projects) Order will lapse after 18 February 2019. For full details of the Budget Speech, please refer to the Singapore Budget website. Post navigation PreviousPrevious post:More e-payment options for customers', metadata={'source': 'https://accountingservices.sg/paying-taxes-2019_1/'}),
#  Document(page_content='Budget 2019 – Overview of Tax Changes News, Latest News By admin_accountingservices January 21, 2019', metadata={'source': 'https://accountingservices.sg/category/latest-news/page/2/'}),
#  Document(page_content='Free online course on starting a business Aspiring entrepreneurs can now tap on ACRA’s new free online course to guide them on their journey in starting a business in Singapore. The “Essentials of Starting a Business” (ESB) programme also covers useful information such as business registration requirements, applying for business licenses, government grants and loans, individual & corporate tax matters, contributions to the Central Provident Fund and personal data protection requirements. Accessible via desktop, tablet and mobile, the course consists of three bite-sized modules and takes only 2 hours to complete. The ESB is ideal for those thinking of setting up a business or have recently set up a business and want the flexibility to learn at their own convenience. Topics Covered Why register your business with ACRA? Types of Business Entities in Singapore Business Licences Government Grants and Loans Fundamentals of Finance SMECEN – integrated software solution for businesses Filing', metadata={'source': 'https://accountingservices.sg/free-online-course-on-starting-a-business/'}),
#  Document(page_content='your business with ACRA? Types of Business Entities in Singapore Business Licences Government Grants and Loans Fundamentals of Finance SMECEN – integrated software solution for businesses Filing Tax Returns Goods and Services Tax CPF Contributions for yourself and your staff Personal Data Protection Act Find out more about the eLearning portal here. Once you have got the understanding of starting a business, don’t forget to check out our services! Accounting, Payroll, Tax, XBRL Filing, Company Secretary and even Web development services to help you get your business started. Post navigation PreviousPrevious post:Register Your Business With ACRA NextNext post:Work passes and permits', metadata={'source': 'https://accountingservices.sg/free-online-course-on-starting-a-business/'}),
#  Document(page_content='Skip to content Home Profile ServicesAccounting Payroll Tax XBRL Filing Corporate Secretarial OthersWeb Development Prices News Contact +65 9362 3460 info@accountingservices.sg +65 9362 3460 +65 9362 3460 Home Profile ServicesAccounting Payroll Tax XBRL Filing Corporate Secretarial OthersWeb Development Prices News Contact Contact You are here: Home Contact Address: 69 Ubi Road 1, #08-30 Oxley Bizhub Singapore 408731 Tel: +65 9362 3460 Email: info@accountingservices.sg Contact Us Socialize With Us, We are your solution. Accounting Services \u200bTel: +65 9362 3460 Email: info@accountingservices.sg WHAT WE OFFER Accounting Payroll Tax XBRL Filing Corporate Secretarial QUICK LINKS Home About Us News Prices Contact Copyright © 2019 Accounting Services. All Rights Reserved. Go to Top', metadata={'source': 'https://accountingservices.sg/contact/'}),
#  Document(page_content='Changes on statutory requirements for AGM and filing of AR Companies due to hold AGMs in the coming months should take note of changes to the timelines for holding AGMs and filing of ARs following a legislative change to the Companies Act which took effect on 31 Aug 2018. Listed companies with FYE ending on or after 31 Aug 2018 must now hold their AGM within four months after FYE and file the AR within five months after FYE, while all other companies must hold the AGM within six months after FYE and file the AR within seven months after the FYE. Alignment of timelines for holding AGMs and filing ARs to the Financial Year End (FYE) To provide greater clarity for companies and reduce the compliance burden, the timelines for holding Annual General Meetings (AGMs) and the filing of annual returns will be aligned with the company’s FYE. To prevent companies from arbitrarily changing their FYE, the following safeguards are put in place: companies must notify the Registrar of their FYE upon', metadata={'source': 'https://accountingservices.sg/reminder-to-hold-annual-general-meeting-agm-and-file-ar-annual-return-on-time/'}),
# ...
#  Document(page_content='Skip to content Home Profile ServicesAccounting Payroll Tax XBRL Filing Corporate Secretarial OthersWeb Development Prices News Contact +65 9362 3460 info@accountingservices.sg +65 9362 3460 +65 9362 3460 Home Profile ServicesAccounting Payroll Tax XBRL Filing Corporate Secretarial OthersWeb Development Prices News Contact Tax You are here: Home Tax A Leading Corporate Tax Filing Services Firm in Singapore Companies incorporated in Singapore are required by law to submit their yearly tax returns, together with all the supporting schedules to IRAS. Business enterprises are becoming more aware of the significant tax impact has on their transactions. If you are on the lookout for a partner in Singapore, look no further than Accounting Services! At Skye, we offer professional corporate taxation services for businesses in Singapore. We are committed to helping your organization to meet the tax compliance obligations by: Help client ensure tax returns are filed promptly All tax deadlines', metadata={'source': 'https://accountingservices.sg/tax/'}),
#  Document(page_content='services for businesses in Singapore. We are committed to helping your organization to meet the tax compliance obligations by: Help client ensure tax returns are filed promptly All tax deadlines duly complied Identify tax incentives, grants and policies to new start-up SMEs, maximise tax benefits allowed by the government Taxation from $350 / annum Services Provided: We are a corporate tax filing services firm based in Singapore. To assist our client in maximising the tax benefits allowed by the government and to avoid penalties, we provide professional corporate taxation services for businesses in Singapore. Below is the full range of tax services provided. Annual filing of Estimated Chargeable Income (ECI) to IRAS. Preparation of Corporate Income Tax Computation. Preparation of Form C/ Form C-S and appendix to IRAS. Handling queries raised by tax authorities. Did You Know... Pursuant to Section 95 of the Singapore Income Tax Act, penalties of up to twice the tax undercharged may be', metadata={'source': 'https://accountingservices.sg/tax/'}),
#  Document(page_content='Form C-S and appendix to IRAS. Handling queries raised by tax authorities. Did You Know... Pursuant to Section 95 of the Singapore Income Tax Act, penalties of up to twice the tax undercharged may be imposed if a taxpayer makes an incorrect return by omitting or underestimating any income or gives incorrect information in relation to any matter affecting the tax payer’s own liability to tax, or the liability of any other person. Goods and Services Tax (GST) In Singapore, a company is obliged to register for Goods and Services Tax (GST) if its revenue is at least $1 million in total value of taxable supplies per year in the course of business. However, if you wish to enjoy the benefit of being GST registered even though you do not exceed $1 million in turnover, you can also register voluntarily if it is beneficial for your business if you meet the conditions. GST preparation can be daunting to business owners who may not have the expertise to do it themselves and they may risk facing', metadata={'source': 'https://accountingservices.sg/tax/'}),
#  Document(page_content='if it is beneficial for your business if you meet the conditions. GST preparation can be daunting to business owners who may not have the expertise to do it themselves and they may risk facing unnecessary penalties from IRAS for erroneous GST submission. This is where our corporate tax filing services come in. As the top accounting firm in Singapore, you can depend on us to manage your tax filing! Services Provided: Application for GST Registration for GST-registered companies Preparation of monthly and quarterly GST Returns Submission of GST Returns to IRAS GST filing and compliance Application for GST de-registration If you have any questions about our professional corporate taxation services in Singapore, feel free to contact us! Accounting Services \u200bTel: +65 9362 3460 Email: info@accountingservices.sg WHAT WE OFFER Accounting Payroll Tax XBRL Filing Corporate Secretarial QUICK LINKS Home About Us News Prices Contact Copyright © 2019 Accounting Services. All Rights Reserved. Go to', metadata={'source': 'https://accountingservices.sg/tax/'}),
#  Document(page_content='WHAT WE OFFER Accounting Payroll Tax XBRL Filing Corporate Secretarial QUICK LINKS Home About Us News Prices Contact Copyright © 2019 Accounting Services. All Rights Reserved. Go to Top', metadata={'source': 'https://accountingservices.sg/tax/'}),
#  Document(page_content='Skip to content Home Profile ServicesAccounting Payroll Tax XBRL Filing Corporate Secretarial OthersWeb Development Prices News Contact +65 9362 3460 info@accountingservices.sg +65 9362 3460 +65 9362 3460 Home Profile ServicesAccounting Payroll Tax XBRL Filing Corporate Secretarial OthersWeb Development Prices News Contact Corporate Secretarial You are here: Home Corporate Secretarial Corporate Secretarial Services in Singapore Too busy to monitor and ensure that your business follows all statutory requirements of Accounting and Corporate Regulatory Authority (“ACRA”)? We are the professional corporate secretarial services provider in Singapore you can rely on. All companies are required to comply with stringent rules and regulations. Failure to comply will result to penalties. While Section 171(1) of the Companies Act (Chapter 50) requires every company to have one or more secretaries who is residing in Singapore and must not be the sole director in the company, you may wish to have', metadata={'source': 'https://accountingservices.sg/corporate-secretarial/'}),
#  Document(page_content="171(1) of the Companies Act (Chapter 50) requires every company to have one or more secretaries who is residing in Singapore and must not be the sole director in the company, you may wish to have someone with the knowledge of the Companies Act (Chapter 50) to provide you with professional advice with regards to corporate matters and ensure that your business meets all statutory filing compliances. This is where Accounting Services, the top corporate secretarial service provider in Singapore, and our packages come in. As the premier accounting firm, we provide professional corporate secretarial services for businesses in Singapore geared towards ensuring regulatory compliance. Learn more about our package by reading on. SKYE'S PROMOTION!! Corporate secretarial service in Singapore package at only S$988! Services Provided: Maintenance of proper registers and minute book Preparation and updating of the corporate constitution of the company Opening of corporate bank account and application", metadata={'source': 'https://accountingservices.sg/corporate-secretarial/'}),
#  Document(page_content='only S$988! Services Provided: Maintenance of proper registers and minute book Preparation and updating of the corporate constitution of the company Opening of corporate bank account and application of bank facilities Preparation of resolutions, including changes in directorship and registered office address Attending to routine secretarial filing Provide administrative support in the preparation of standard annual general meeting documents Monitoring and notifying of deadlines and facilitate compliance for the holding of AGM meetings and filing of annual returns with ACRA Ensuring that the company meets all its legal obligation Not limited to the above corporate secretarial services includes: Incorporation of Singapore private limited company Striking off Singapore private limited company Nominee corporate secretary services Want to find out more about our professional corporate secretarial services in Singapore? Leave us a message today! Accounting Services \u200bTel: +65 9362 3460 Email:', metadata={'source': 'https://accountingservices.sg/corporate-secretarial/'}),
#  Document(page_content='Nominee corporate secretary services Want to find out more about our professional corporate secretarial services in Singapore? Leave us a message today! Accounting Services \u200bTel: +65 9362 3460 Email: info@accountingservices.sg WHAT WE OFFER Accounting Payroll Tax XBRL Filing Corporate Secretarial QUICK LINKS Home About Us News Prices Contact Copyright © 2019 Accounting Services. All Rights Reserved. Go to Top', metadata={'source': 'https://accountingservices.sg/corporate-secretarial/'}),
#  Document(page_content='Types of Business Entities - Which is the suitable one for you? Have you always been wondering which business structure you should choose before starting your own business? It is important to know the differences of these 4 types of business entities before you decide: Company Business Limited Liability Partnership Limited Partnership We will start with the simplest form – Business A business can be a sole-proprietorship with one owner or a partnership consisting of 2 to 20 owners. Business owners are personally liable for the debts and losses of the business, which is also known as unlimited liability. The next business entity, Company, usually has the words Pte Ltd or Ltd as part of its name. One of the advantages of owning a company is that the shareholders have limited liability, so they are not personally liable for the debts and losses of the Company. Limited Liability Partnership (LLP) is a partnership with a minimum of two partners and they have limited liability, however, for', metadata={'source': 'https://accountingservices.sg/choosing-your-business-structure/'}),
#  Document(page_content='are not personally liable for the debts and losses of the Company. Limited Liability Partnership (LLP) is a partnership with a minimum of two partners and they have limited liability, however, for Limited Partnership (LP), there needs to be a general partner and a limited partner. Whilst the general partner is personally liable for debts and losses of the LP, the limited partner enjoys limited liability. Here’s a few questions to ask yourself while choosing an entity: Do you plan to own the business by yourself or together with other people? How much capital are you prepared/willing to invest? Are you able to finance your business solely or would you need finance from other persons as well? Do you prefer Limited or Unlimited liability? If you have your answers for the above questions and have decided on an entity, make sure to adhere to the following rules for opening your business: At least 18 years old All entities must have at least one person who is residing in Singapore For', metadata={'source': 'https://accountingservices.sg/choosing-your-business-structure/'}),
#  Document(page_content='and have decided on an entity, make sure to adhere to the following rules for opening your business: At least 18 years old All entities must have at least one person who is residing in Singapore For Business, LLP and LP, there is a requirement that the owner or partner’s Medisave must be paid up with a CPF board at all times Comply with all requirements for registration and post-registration Ready to register your own business? Do also find out if you are required to register your business with ACRA as well as the advantages of registering with ACRA. If you still want to learn more about starting a business, fret not, there is a free online course to clear all your doubts! Post navigation PreviousPrevious post:Address Registered for your Company NextNext post:Start-Up Kit for New Companies', metadata={'source': 'https://accountingservices.sg/choosing-your-business-structure/'}),
#  Document(page_content='Skip to content Home Profile ServicesAccounting Payroll Tax XBRL Filing Corporate Secretarial OthersWeb Development Prices News Contact +65 9362 3460 info@accountingservices.sg +65 9362 3460 +65 9362 3460 Home Profile ServicesAccounting Payroll Tax XBRL Filing Corporate Secretarial OthersWeb Development Prices News Contact XBRL Filing You are here: Home XBRL Filing XBRL Filing Services in Singapore With effect from 3 March 2014, companies will need file their financial statements in XBRL in accordance with the revised XBRL filing requirements. This is prepared through using ACRA’s offline software application-BizFinx filing system so companies can prepare XBRL financial statements in accordance with the revised XBRL filing requirements. If you are looking for a XBRL filing services company to assist your business in Singapore, look no further than Accounting Services. As an experienced accounting services provider in Singapore, our XBRL filing services are unrivalled. Our team of', metadata={'source': 'https://accountingservices.sg/xbrl-filing/'}),
#  Document(page_content='to assist your business in Singapore, look no further than Accounting Services. As an experienced accounting services provider in Singapore, our XBRL filing services are unrivalled. Our team of experts in Singapore will make sure you obtain all financial statements in the appropriate XBRL format. Our XBRL filing services are administered in accordance to the regulations imposed by ACRA. Learn more about how we can help you business by reading on! Who needs to file? Singapore incorporated companies (unlimited or limited by shares) are required to file a full set of their financial statements in XBRL format, according to a minimum requirement list within the new ACRA Taxonomy 2013 with ACRA. This filing requirement is however, exempted for the following companies who will only need to file a PDF copy of its financial statements with Financial Statements Highlights (FSH) in XBRL format: Specific companies regulated by MAS, i.e. commercial banks, merchant banks, licensed insurers, finance', metadata={'source': 'https://accountingservices.sg/xbrl-filing/'}),
#  Document(page_content='a PDF copy of its financial statements with Financial Statements Highlights (FSH) in XBRL format: Specific companies regulated by MAS, i.e. commercial banks, merchant banks, licensed insurers, finance companies regulated by MAS; and Companies allowed by law to prepare accounts in accordance with accounting standards other than SFRS, SFRS for Small Entities and IFRS Companies limited by guarantee and foreign companies and their local branches will continue to file only a full set of their financial statement in PDF format to ACRA. Who is responsible for the accuracy of XBRL filing? It is director’s responsibility to review and ensure that the content of the Company’s XBRL filing is complete and consistent before authorizing their company or authorized person to submit the information on behalf of the Company to ACRA. Questions about our professional XBRL Filing services in Singapore? Do not hesitate to send us your enquiry! Accounting Services \u200bTel: +65 9362 3460 Email:', metadata={'source': 'https://accountingservices.sg/xbrl-filing/'}),
#  Document(page_content='on behalf of the Company to ACRA. Questions about our professional XBRL Filing services in Singapore? Do not hesitate to send us your enquiry! Accounting Services \u200bTel: +65 9362 3460 Email: info@accountingservices.sg WHAT WE OFFER Accounting Payroll Tax XBRL Filing Corporate Secretarial QUICK LINKS Home About Us News Prices Contact Copyright © 2019 Accounting Services. All Rights Reserved. Go to Top', metadata={'source': 'https://accountingservices.sg/xbrl-filing/'})]

# %%
# # Define embedding model
# OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# store = Chroma.from_documents(
#     data_split, embeddings, collection_name="acs", persist_directory="db"
# )

# store.persist()
# store = None
# Out:
# Using embedded DuckDB with persistence: data will be stored in: db

# %% [markdown]
# ### Chroma DB persisted

# %%
# Define embedding model
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)
store = Chroma(
    collection_name="acs", persist_directory="db", embedding_function=embeddings
)
store._collection
# Out:
# Using embedded DuckDB with persistence: data will be stored in: db
# Collection(name=acs)

# %%
llm = ChatOpenAI(
    model_name="gpt-3.5-turbo",
    temperature=0,
    openai_api_key=OPENAI_API_KEY,
    max_tokens=512,
)

# %%
sales_template = """
As a customer marketing bot, your goal is to provide accurate and helpful information about Elliot & Co.
You should answer user inquiries based on the context provided and avoid making up answers.
If you don't know the answer, simply state that you don't know.
Remember to provide relevant information about how Elliot & Co can assist the user through its services, strengths and benefits.

{context}
=========
Question: {question}
"""

SALES_PROMPT = PromptTemplate(
    template=sales_template, input_variables=["context", "question"]
)

sales_qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=store.as_retriever(),
    chain_type_kwargs={"prompt": SALES_PROMPT},
)

# %%
print(sales_qa.run("What does the company do?"))

# %% [markdown]
# ### `RetrievalQAWithSourcesChain` (The answers aren't that good compared to the above method)

# %%
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)


system_template = """
As a customer marketing bot, your goal is to provide accurate and helpful information about Elliot & Co.
You should answer user inquiries based on the context provided and avoid making up answers.
If you don't know the answer, simply state that you don't know.
Remember to provide relevant information about how Elliot & Co can assist the user through its services, strengths and benefits.

{context}
=========
Question: {question}
"""

messages = [
    SystemMessagePromptTemplate.from_template(system_template),
    HumanMessagePromptTemplate.from_template("{question}"),
]
prompt = ChatPromptTemplate.from_messages(messages)

# %%
from langchain.chains import RetrievalQAWithSourcesChain

chain = RetrievalQAWithSourcesChain.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=store.as_retriever(),
    return_source_documents=True,
)

# %%
from IPython.display import display, Markdown


def print_result(query, result):
    output_text = f"""### Question:\n{query}\n### Answer:\n{result['answer']}\n### Sources:\n{result['sources']}
    """
    display(Markdown(output_text))

# %%
query = "What is this company?"
result = chain(query)

# %%
print_result(query, result)

# %%
query = "What does retainer options for 6 months mean?"
result = chain(query)
print_result(query, result)

# %%
query = "I am a company that provides a chatbot as a service. How can you help?"
result = chain(query)
print_result(query, result)
