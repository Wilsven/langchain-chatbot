# %%
# https://github.com/tomasonjo/blogs/blob/master/neo4jdocs/neo4j_support_bot.ipynb
# %pip install langchain==0.0.142 openai==0.27.4 beautifulsoup4==4.12.2 chromadb==0.3.21

# %%
import os
import dotenv

import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd

from langchain.document_loaders import (
    # GitLoader,
    # YoutubeLoader,
    # DataFrameLoader,
    UnstructuredURLLoader,
)
from langchain.text_splitter import CharacterTextSplitter

import tiktoken

# from langchain.schema import Document
from langchain.embeddings import OpenAIEmbeddings
from langchain.chat_models import ChatOpenAI
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.agents import initialize_agent, Tool

from crawl import crawl, clean, strip_content

# loads .env file with your OPENAI_API_KEY
dotenv.load_dotenv()
# Out:
# True

# %%
# Regex pattern to match a URL
HTTP_URL_PATTERN = r"^http[s]*://.+"

# Define root domain to crawl
DOMAIN = "contactout.com"
FULL_URL = "https://contactout.com/"

# %% [markdown]
# ### Embedding documents for the first time

# %%
seen = crawl(FULL_URL, HTTP_URL_PATTERN)
print(len(seen))
# Out:
# https://contactout.com/
# https://contactout.com/chrome-extension
# https://contactout.com/integrations
# https://contactout.com/clients/bdex/
# https://contactout.com/recruiters
# https://contactout.com/clients/spreetail/
# https://contactout.com/contact
# https://contactout.com/optout
# https://contactout.com/privacy
# https://contactout.com/privacy_policy
# https://contactout.com/privacy_data_subjects
# https://contactout.com
# https://contactout.com/terms
# https://contactout.com/search-portal
# https://contactout.com/pricing
# https://contactout.com/meeting?utm_source=pricing
# https://contactout.com/contact_us
# https://contactout.com/dashboard/search
# https://contactout.com/integrations-feature
# https://contactout.com/integrations/
# https://contactout.com/sales-users
# https://contactout.com/meeting?utm_source=talk_to_sales_use_case
# https://contactout.com/clients
# https://contactout.com/clients/spreetail
# https://contactout.com/clients/worth-search
# https://contactout.com/clients/txt-international
# https://contactout.com/clients/ivy-exec
# https://contactout.com/clients/group-m
# https://contactout.com/clients/contract-recruiter
# https://contactout.com/clients/bdex
# https://contactout.com/clients/the-power-hive
# https://contactout.com/our-data
# https://contactout.com/alternative
# https://contactout.com/alternative/lusha-vs-contactout
# https://contactout.com/dashboard/data-enrichment
# https://contactout.com/alternative/zoominfo-vs-contactout
# https://contactout.com/alternative/apollo-vs-contactout
# https://contactout.com/data-enrichment-feature
# https://contactout.com/meeting
# 39

# %%
clean = clean(seen)
print(len(clean))
# Out:
# 39

# %%
urls = list(clean)

# Without headers User-Agent, results in forbidden 403
loader = UnstructuredURLLoader(urls=urls, headers={"User-Agent": "Mozilla/5.0"})
data = loader.load()
print(len(data))
# Out:
# 39

# %%
for d in data:
    new_content = strip_content(d.page_content)
    d.page_content = new_content

# %%
# Define text chunk strategy
splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200, separator=" ")
# Split documents into chunks
data_split = splitter.split_documents(data)
print(len(data_split))
# Out:
# 282

# %%
data_split
# Out:
# [Document(page_content='Use Cases Sales Unlimited sales users for $299 Recruiters Speed up hiring of top talents Features Search Portal Find the right prospects quickly with 20+ search filters Email Campaigns Automate & accelerate your outreach Chrome Extension Supercharge your prospecting on LinkedIn and across the the web Integrations Power up your existing tools with ContactOut data Data Enrichment Know your leads in minutes with ContactOut data API Integrate ContactOut data into your workflow Use Cases Sales Recruiters Features Search Portal Email Campaigns Chrome Extension Integrations Data Enrichment API Our Data Clients Pricing Support Guides Get a demo Login Sign up for free Login The Power Hive: Improving Recruitment with ContactOut ContactOut is a massive advantage. My advice is do not go out and buy ‘shiny new toys’. You’ve got to go try something as simple and accurate as ContactOut. Keith Southern Co-Founder and Partner at The Power Hive The Power Hive The Power Hive has branded itself as a', metadata={'source': 'https://contactout.com/clients/the-power-hive'}),
#  Document(page_content='buy ‘shiny new toys’. You’ve got to go try something as simple and accurate as ContactOut. Keith Southern Co-Founder and Partner at The Power Hive The Power Hive The Power Hive has branded itself as a “collective of the most forward thinking and experienced recruitment leaders”. That they are. They are a virtual network based in Manchester, United Kingdom. They have achieved a vast network of today’s leaders in recruitment through the use of ContactOut. Their platform is a space to share ideas and develop peer-to-peer learning. Within the Power Hive network, they use ContactOut to be the best they can be in the recruiting industry. Highlights Challenges Expanding the Power Hive network through sourcing accurate contact information for potential subscribers and supplies Solution The Power Hive using ContactOut as their “go to” scraping tool. Results A network of 150+ members in the community. Challenges: We sat down with Keith Southern who is the Co-Founder and Partner of the Power', metadata={'source': 'https://contactout.com/clients/the-power-hive'}),
#  Document(page_content='Hive using ContactOut as their “go to” scraping tool. Results A network of 150+ members in the community. Challenges: We sat down with Keith Southern who is the Co-Founder and Partner of the Power Hive. Keith has been using ContactOut for roughly 5 years. The first 2 years were with a previous organization and the past three years have been with the Power Hive. As a Co-Founder and Partner, Keith wants to see the Power Hive community grow. The only way to do that is to increase the subscribers and the suppliers. Keith knew when he helped found the Power Hive, that ContactOut was going to be their top tool for scraping contact information for potential subscribers and suppliers. 200 contacts a week breeds about 180 connections. Success is growing 10-12 new members each month. We are on target for next year’s goal of 250+ new members. Keith Southern Co-Founder and Partner at The Power Hive There are 6,000 new recruitment agencies in the UK. Speed is key when trying to keep up with the', metadata={'source': 'https://contactout.com/clients/the-power-hive'}),
#  Document(page_content='for next year’s goal of 250+ new members. Keith Southern Co-Founder and Partner at The Power Hive There are 6,000 new recruitment agencies in the UK. Speed is key when trying to keep up with the expanding recruitment industry. Keith Southern Co-Founder and Partner at The Power Hive Solution: The Power Hive has always used ContactOut because of its reliability and accessibility. Keith walked us through how his team uses ContactOut. The sales team in particular, relies on ContactOut the most. Their Friday afternoon consists of pulling together the contact information of 200 contacts they hope to connect with the following week. The team connects with these prospects via phone call and email. Because of this, it is incredibly important that the information they receive through ContactOut is accurate to make that connection. 75% of the world’s professional’s contact 200 contacts weekly The Power Hive uses a reverse engineering process. 120 calls in one week should bring in about 3-4 new', metadata={'source': 'https://contactout.com/clients/the-power-hive'}),
#  Document(page_content='accurate to make that connection. 75% of the world’s professional’s contact 200 contacts weekly The Power Hive uses a reverse engineering process. 120 calls in one week should bring in about 3-4 new members per week. The more people we speak to, the more members join. Keith Southern Co-Founder and Partner at The Power Hive Results: Keith and his team have seen great success through using ContactOut, even internally. As mentioned before, they are already on track to meeting next year’s goal of new members. Keith had mentioned a particular time recently where ContactOut was proven to be truly valuable to him and the Power Hive family. He was looking to fill a project management role on his team within a very specific niche. Through an advanced search, Keith retrieved 42 contacts. That led to 7 interviews, 2 offers, and 1 placement. Keith had mapped out his prospects on ContactOut within hours. The speed and accuracy of ContactOut’s Chrome extension led to a placement within 2 weeks.', metadata={'source': 'https://contactout.com/clients/the-power-hive'}),
#  Document(page_content='to 7 interviews, 2 offers, and 1 placement. Keith had mapped out his prospects on ContactOut within hours. The speed and accuracy of ContactOut’s Chrome extension led to a placement within 2 weeks. Speed, accessibility, accuracy. You will hear a lot of recruitment agency owners talk about ratios. What people really care about is accurate information to make a placement and make a deal. Keith Southern Co-Founder and Partner at The Power Hive Take the ContactOut challenge Let your recruiters test our candidate contact data against any other provider - and experience how ContactOut leads the market in both Sign up to get 10 free credits Get Chrome extension (it’s free!) 40 free contact reveals per month No credit card required 500k+ users GDPR and CCPA aligned Register Sign up with Google Sign up with Microsoft Outlook Register Already have an account? Log In Problems? Email [email protected] © 2023 ContactOut. All rights reserved. Directory Email Finder Email Verifier People Search Best', metadata={'source': 'https://contactout.com/clients/the-power-hive'}),
#  Document(page_content='up with Microsoft Outlook Register Already have an account? Log In Problems? Email [email protected] © 2023 ContactOut. All rights reserved. Directory Email Finder Email Verifier People Search Best Blogger Outreach Recruitment Sales Platforms Staffing Lead Generation Talent Acquisition Social Media Marketing Sales Platform Sales Engagement Sales Leads Recruiting Automation B2B Data Revenue Operations Email Verification Email Tracking Account Based Marketing Blogger Outreach Lead Intelligence Marketing Intelligence Diversity Recruiting Sales Software Data Enrichment Identity Verification Technology Lookup Sales Intelligence Sales Tools Staffing Software Email Marketing Market Intelligence Influencer Marketing Recruitment Marketing Link Building SMS Marketing Recruitment Software SEO Tools Content Marketing Sales Prospecting Demand Generation Email Lists A1 A2 A3 A4 B1 B2 B3 B4 C1 C2 C3 C4 D1 D2 D3 D4 E1 E2 E3 E4 F1 F2 F3 F4 G1 G2 G3 G4 H1 H2 H3 H4 I1 I2 I3 I4 J1 J2 J3 J4 K1 K2 K3 K4 L1', metadata={'source': 'https://contactout.com/clients/the-power-hive'}),
#  Document(page_content='Content Marketing Sales Prospecting Demand Generation Email Lists A1 A2 A3 A4 B1 B2 B3 B4 C1 C2 C3 C4 D1 D2 D3 D4 E1 E2 E3 E4 F1 F2 F3 F4 G1 G2 G3 G4 H1 H2 H3 H4 I1 I2 I3 I4 J1 J2 J3 J4 K1 K2 K3 K4 L1 L2 L3 L4 M1 M2 M3 M4 N1 N2 N3 N4 O1 O2 O3 O4 P1 P2 P3 P4 Q1 Q2 Q3 Q4 R1 R2 R3 R4 S1 S2 S3 S4 T1 T2 T3 T4 U1 U2 U3 U4 V1 V2 V3 V4 W1 W2 W3 W4 X1 X2 X3 X4 Y1 Y2 Y3 Y4 Z1 Z2 Z3 Z4 Product Features Our Data Pricing Use Cases Sales Recruiters Use Cases Sales Recruiters Features Search Portal Email Campaigns Chrome Extension Company About Us Careers Contact Us Customer Stories Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info Resources Blog Guides Knowledge Base Video Tutorials ContactOut Alternatives Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info', metadata={'source': 'https://contactout.com/clients/the-power-hive'}),
#  Document(page_content='Use Cases Sales Unlimited sales users for $299 Recruiters Speed up hiring of top talents Features Search Portal Find the right prospects quickly with 20+ search filters Email Campaigns Automate & accelerate your outreach Chrome Extension Supercharge your prospecting on LinkedIn and across the the web Integrations Power up your existing tools with ContactOut data Data Enrichment Know your leads in minutes with ContactOut data API Integrate ContactOut data into your workflow Use Cases Sales Recruiters Features Search Portal Email Campaigns Chrome Extension Integrations Data Enrichment API Our Data Clients Pricing Support Guides Get a demo Login Sign up for free Login Spreetail Dominates Ecommerce with Talent Found using ContactOut With ContactOut we’ve been able to source at least 50 excellent candidates a week. Nick Sanders Recruitment Manager at Spreetail Spreetail Spreetail is currently dominating eCommerce as a company that connects brands to customers wherever they like to shop', metadata={'source': 'https://contactout.com/clients/spreetail/'}),
#  Document(page_content='candidates a week. Nick Sanders Recruitment Manager at Spreetail Spreetail Spreetail is currently dominating eCommerce as a company that connects brands to customers wherever they like to shop online. They pride themselves on being an end-to-end eCommerce growth partner. They have fulfillment centers in 8 cities across 6 states working with giants like Amazon, Walmart, and Wayfair. Highlights Challenges Not enough sourcing value Even with competitor’s software, kept resorting back to LinkedIn Demand for candidates is high, the sourcing process is slow Solution ContactOut’s inventory of 75% of the world’s professional’s contact information ContactOut’s Chrome extension is one-click and done ContactOut’s 97% accuracy rate saves time by avoiding bounce back emails Results Spreetail team has grown by 20 talented individuals in 3 months More than 50 candidates are sourced per week Averaging 6-8 individuals onboarded per month Challenges: We sat down with Nick Sanders, a Recruitment Manager', metadata={'source': 'https://contactout.com/clients/spreetail/'}),
#  Document(page_content='grown by 20 talented individuals in 3 months More than 50 candidates are sourced per week Averaging 6-8 individuals onboarded per month Challenges: We sat down with Nick Sanders, a Recruitment Manager for Spreetail, to see how he has used ContactOut as his secret weapon to grow the Spreetail team. Nick had heard about ContactOut as a leading sourcing tool and decided to try it himself through a free trial of the software. Nick claims, “everyone I have talked to sees the value in ContactOut.” Before using ContactOut, Spreetail relied heavily on the use of LinkedIn and competitor’s software for retrieving contact information for potential candidates. As eCommerce has continued to grow, so has Spreetail. This has led to a huge increase in demand for qualified candidates to help support Spreetail’s mission. ContactOut has allowed us to quickly get candidates in our pipeline and has helped us fill our open roles faster. Nick Sanders Recruitment Manager at Spreetail Solution: With', metadata={'source': 'https://contactout.com/clients/spreetail/'}),
#  Document(page_content='Spreetail’s mission. ContactOut has allowed us to quickly get candidates in our pipeline and has helped us fill our open roles faster. Nick Sanders Recruitment Manager at Spreetail Solution: With ContactOut’s Chrome extension, Nick gained access to 75% of the world’s professionals with the click of a button. Nick claims, “it’s as easy as clicking ‘email’, getting it, and go.” Not only is the tool fast, but it has a 97% accuracy rate which is a real-time saver for recruiters like Nick who hate to get that dreaded bounce-back email. 75% of the world’s professionals are available 97% accuracy rate the correct information Not many tools can get you the correct email information, let alone a personal cellphone number like ContactOut does. Nick Sanders Recruitment Manager at Spreetail Having access to personal phone numbers is extremely valuable. It means I can text my candidates and get responses faster than I would via LinkedIn. Nick Sanders Recruitment Manager at Spreetail Results: It is', metadata={'source': 'https://contactout.com/clients/spreetail/'}),
#  Document(page_content='to personal phone numbers is extremely valuable. It means I can text my candidates and get responses faster than I would via LinkedIn. Nick Sanders Recruitment Manager at Spreetail Results: It is pretty safe to say that Nick and his team at Spreetail have found their secret weapon for recruiting top professionals in their industry through the use of ContactOut. Their team has grown by 20 talented individuals in 3 months through the use of ContactOut. Nick is also able to stay ahead of the demand of the business by sourcing more than 50 potential candidates per week leading to 6-8 onboardings per month. Nick is very confident that he and his team will continue to use ContactOut to support the growth of their organization and stay ahead of competitors by acquiring top talent. ContactOut is the best scraping tool on the market easily. I don’t see us going away from it. Nick Sanders Recruitment Manager at Spreetail As a Recruitment Manager, my success is determined by the quality and', metadata={'source': 'https://contactout.com/clients/spreetail/'}),
#  Document(page_content='is the best scraping tool on the market easily. I don’t see us going away from it. Nick Sanders Recruitment Manager at Spreetail As a Recruitment Manager, my success is determined by the quality and quantity of the candidates that I can get through the pipeline. With ContactOut I am able to exceed my goal of 4 onboardings per month. Nick Sanders Recruitment Manager at Spreetail Take the ContactOut challenge Let your recruiters test our candidate contact data against any other provider - and experience how ContactOut leads the market in both Sign up to get 10 free credits Get Chrome extension (it’s free!) 40 free contact reveals per month No credit card required 500k+ users GDPR and CCPA aligned Register Sign up with Google Sign up with Microsoft Outlook Register Already have an account? Log In Problems? Email [email protected] © 2023 ContactOut. All rights reserved. Directory Email Finder Email Verifier People Search Best Blogger Outreach Recruitment Sales Platforms Staffing Lead', metadata={'source': 'https://contactout.com/clients/spreetail/'}),
#  Document(page_content='Log In Problems? Email [email protected] © 2023 ContactOut. All rights reserved. Directory Email Finder Email Verifier People Search Best Blogger Outreach Recruitment Sales Platforms Staffing Lead Generation Talent Acquisition Social Media Marketing Sales Platform Sales Engagement Sales Leads Recruiting Automation B2B Data Revenue Operations Email Verification Email Tracking Account Based Marketing Blogger Outreach Lead Intelligence Marketing Intelligence Diversity Recruiting Sales Software Data Enrichment Identity Verification Technology Lookup Sales Intelligence Sales Tools Staffing Software Email Marketing Market Intelligence Influencer Marketing Recruitment Marketing Link Building SMS Marketing Recruitment Software SEO Tools Content Marketing Sales Prospecting Demand Generation Email Lists A1 A2 A3 A4 B1 B2 B3 B4 C1 C2 C3 C4 D1 D2 D3 D4 E1 E2 E3 E4 F1 F2 F3 F4 G1 G2 G3 G4 H1 H2 H3 H4 I1 I2 I3 I4 J1 J2 J3 J4 K1 K2 K3 K4 L1 L2 L3 L4 M1 M2 M3 M4 N1 N2 N3 N4 O1 O2 O3 O4 P1 P2 P3 P4 Q1', metadata={'source': 'https://contactout.com/clients/spreetail/'}),
#  Document(page_content='Lists A1 A2 A3 A4 B1 B2 B3 B4 C1 C2 C3 C4 D1 D2 D3 D4 E1 E2 E3 E4 F1 F2 F3 F4 G1 G2 G3 G4 H1 H2 H3 H4 I1 I2 I3 I4 J1 J2 J3 J4 K1 K2 K3 K4 L1 L2 L3 L4 M1 M2 M3 M4 N1 N2 N3 N4 O1 O2 O3 O4 P1 P2 P3 P4 Q1 Q2 Q3 Q4 R1 R2 R3 R4 S1 S2 S3 S4 T1 T2 T3 T4 U1 U2 U3 U4 V1 V2 V3 V4 W1 W2 W3 W4 X1 X2 X3 X4 Y1 Y2 Y3 Y4 Z1 Z2 Z3 Z4 Product Features Our Data Pricing Use Cases Sales Recruiters Use Cases Sales Recruiters Features Search Portal Email Campaigns Chrome Extension Company About Us Careers Contact Us Customer Stories Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info Resources Blog Guides Knowledge Base Video Tutorials ContactOut Alternatives Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info', metadata={'source': 'https://contactout.com/clients/spreetail/'}),
#  Document(page_content="Use Cases Sales Unlimited sales users for $299 Recruiters Speed up hiring of top talents Features Search Portal Find the right prospects quickly with 20+ search filters Email Campaigns Automate & accelerate your outreach Chrome Extension Supercharge your prospecting on LinkedIn and across the the web Integrations Power up your existing tools with ContactOut data Data Enrichment Know your leads in minutes with ContactOut data API Integrate ContactOut data into your workflow Use Cases Sales Recruiters Features Search Portal Email Campaigns Chrome Extension Integrations Data Enrichment API Our Data Clients Pricing Support Guides Get a demo Login Sign up for free Login Login Welcome back! Sign in with Google Sign in with Microsoft Outlook or Don't have an account? Sign up Forgot your Password?", metadata={'source': 'https://contactout.com/integrations'}),
#  Document(page_content='Use Cases Sales Unlimited sales users for $299 Recruiters Speed up hiring of top talents Features Search Portal Find the right prospects quickly with 20+ search filters Email Campaigns Automate & accelerate your outreach Chrome Extension Supercharge your prospecting on LinkedIn and across the the web Integrations Power up your existing tools with ContactOut data Data Enrichment Know your leads in minutes with ContactOut data API Integrate ContactOut data into your workflow Use Cases Sales Recruiters Features Search Portal Email Campaigns Chrome Extension Integrations Data Enrichment API Our Data Clients Pricing Support Guides Get a demo Login Sign up for free Login Search Portal Find quality prospects fast— all from one place Instant access to 300M professionals from 36M companies with filters like seniority and departments to prospect faster. Try a free search Trusted by 1.4M recruiters and sales reps from Fortune 500 companies Prospect 10x faster Search 300M professionals with 20+', metadata={'source': 'https://contactout.com/search-portal'}),
#  Document(page_content='filters like seniority and departments to prospect faster. Try a free search Trusted by 1.4M recruiters and sales reps from Fortune 500 companies Prospect 10x faster Search 300M professionals with 20+ data attributes like seniority, departments and technologies used. Seamless workflows email campaigns in one-click. Save to your CRM & ATS instantly. Vast & accurate data Access 300M+ personal and work emails. Triple verified B2B data with 99% confidence. Privacy compliant Our data is compliant with GDPR and USA privacy laws. Prospect with confidence. People & Companies Search Find the right prospects quickly Prospect 300M professionals with 20+ data attributes. Access millions of verified emails and direct dials. List building Generate endless quality leads effortlessly Save and sync to your CRM & ATS instantly. Export search results to CSV in one-click. Seamless engagement Connect with prospects immediately Add prospects to email campaigns in one-click. Follow up from your CRM & ATS', metadata={'source': 'https://contactout.com/search-portal'}),
#  Document(page_content='your CRM & ATS instantly. Export search results to CSV in one-click. Seamless engagement Connect with prospects immediately Add prospects to email campaigns in one-click. Follow up from your CRM & ATS right away. Prospect faster with the most accurate data ever CCPA Compliant GDPR Compliant Triple-verified with 99% Confidence 150M Personal Emails 200M Work Emails 100M Direct Dials 300M Professional Profiles 30M Company Profiles Data Attributes Find the right prospects with laser precision Search across 20+ data points to pinpoint the right people and companies more effectively and efficiently. Learn more Job Titles Companies Revenue Skills Locations Company Size Departments Technologies Used Testimonials Hear what our customers have to say “This is such a great and simple tool to use.” Tobia St Germain Google "Find personal mails seamlessly. Thanks for this tool!" Ekin Bayildiran J.P. Morgan “Very easy to use, and it gives contact details that are not available on others I have used.”', metadata={'source': 'https://contactout.com/search-portal'}),
#  Document(page_content='St Germain Google "Find personal mails seamlessly. Thanks for this tool!" Ekin Bayildiran J.P. Morgan “Very easy to use, and it gives contact details that are not available on others I have used.” Barbara Ball Societe Generale “Love it! I use it every day.” Camille Verdier CNN “Great email tool. I\'ve used a few other services and ContactOut is the easiest one to use.” Jon Nowakowski Robert Half “Excellent product, very small chance of error.” Farida Charania HSBC “This is definitely my preferred extension for finding email addresses. It requires the least amount of effort to help find information needed. Keep up the great work!” Suzanne Huynh PwC “Love this extension and would recommend it to anyone looking for a tool to find email addresses.” Evan M. Wolfson Yelp “Great product! ContactOut has tripled the yield of our InMail strategy on LinkedIn (which isn\'t delivering us ROI anymore).” Ryan Brogan WarnerMedia Read more customer success stories Testimonials Hear what our customershave', metadata={'source': 'https://contactout.com/search-portal'}),
#  Document(page_content='has tripled the yield of our InMail strategy on LinkedIn (which isn\'t delivering us ROI anymore).” Ryan Brogan WarnerMedia Read more customer success stories Testimonials Hear what our customershave to say “This is such a great and simple tool to use.” Tobia St Germain Google "Find personal mails seamlessly. Thanks for this tool!" Ekin Bayildiran JP Morgan “Very easy to use, and it gives contact details that are not available on others I have used.” Barbara Ball Societe Generale “Love it! I use it every day.” Camille Verdier CNN “Great email tool. I\'ve used a few other services and ContactOut is the easiest one to use.” Jon Nowakowski Robert Half “Excellent product, very small chance of error.” Farida Charania HSBC “This is definitely my preferred extension for finding email addresses.” Suzanne Huynh PwC “Love this extension and would recommend it to anyone looking for a tool to find email addresses.” Evan M. Wolfson Yelp "Great product! ContactOut has tripled the yield of our InMail', metadata={'source': 'https://contactout.com/search-portal'}),
#  Document(page_content='Suzanne Huynh PwC “Love this extension and would recommend it to anyone looking for a tool to find email addresses.” Evan M. Wolfson Yelp "Great product! ContactOut has tripled the yield of our InMail strategy on LinkedIn." Ryan Brogan WarnerMedia Read more customer success stories “For us, this is it. We’ve got to use ContactOut. ContactOut helps us connect with people I am not currently connected to but need their contact info rather quickly. It helps you do your job correctly and more efficiently.” Brian Hathway Vice President of Business Development, BDEX Won New Big Clients such as Amazon, Estee Lauder & Citibank 2x Sales Outputs With increased speed & accuracy in prospecting More Sales Closed within weeks from first contact Read customer story Top-ranked Lead Intelligence solution on G2 Crowd G2 Crowd Ratings Comparison for 8.9 Lead Validation 9.1 Lead Enrichment 8.8 Lead Quality 8.9 Lead Analysis 9.2 Browser Extension 8.5 Lead Validation 8.5 Lead Enrichment 8.3 Lead Quality 8.3', metadata={'source': 'https://contactout.com/search-portal'}),
#  Document(page_content='G2 Crowd G2 Crowd Ratings Comparison for 8.9 Lead Validation 9.1 Lead Enrichment 8.8 Lead Quality 8.9 Lead Analysis 9.2 Browser Extension 8.5 Lead Validation 8.5 Lead Enrichment 8.3 Lead Quality 8.3 Lead Analysis 8.7 Browser Extension 8.9 Lead Validation 8.8 Lead Enrichment 8.9 Lead Quality 8.7 Lead Analysis 9.3 Browser Extension 7.9 Lead Validation 7.9 Lead Enrichment 7.9 Lead Quality 7.7 Lead Analysis 8.9 Browser Extension 8.9 Lead Validation 9.1 Lead Enrichment 8.8 Lead Quality 8.9 Lead Analysis 9.2 Browser Extension 8.5 Lead Validation 8.5 Lead Enrichment 8.3 Lead Quality 8.3 Lead Analysis 8.7 Browser Extension 8.9 Lead Validation 8.8 Lead Enrichment 8.9 Lead Quality 8.7 Lead Analysis 9.3 Browser Extension 7.9 Lead Validation 7.9 Lead Enrichment 7.9 Lead Quality 7.7 Lead Analysis 8.9 Browser Extension Compare ContactOut with other vendors Compare ContactOut with other vendors Reach the right prospects with ContactOut Engage with confidence using ContactOut’s triple-verified emails', metadata={'source': 'https://contactout.com/search-portal'}),
#  Document(page_content='Browser Extension Compare ContactOut with other vendors Compare ContactOut with other vendors Reach the right prospects with ContactOut Engage with confidence using ContactOut’s triple-verified emails and phone numbers. Sign up to get 40 free credits Get Chrome extension Sign up to get 40 free credits No credit card required. Cancel anytime. © 2023 ContactOut. All rights reserved. Directory Email Finder Email Verifier People Search Best Blogger Outreach Recruitment Sales Platforms Staffing Lead Generation Talent Acquisition Social Media Marketing Sales Platform Sales Engagement Sales Leads Recruiting Automation B2B Data Revenue Operations Email Verification Email Tracking Account Based Marketing Blogger Outreach Lead Intelligence Marketing Intelligence Diversity Recruiting Sales Software Data Enrichment Identity Verification Technology Lookup Sales Intelligence Sales Tools Staffing Software Email Marketing Market Intelligence Influencer Marketing Recruitment Marketing Link Building SMS', metadata={'source': 'https://contactout.com/search-portal'}),
#  Document(page_content='Enrichment Identity Verification Technology Lookup Sales Intelligence Sales Tools Staffing Software Email Marketing Market Intelligence Influencer Marketing Recruitment Marketing Link Building SMS Marketing Recruitment Software SEO Tools Content Marketing Sales Prospecting Demand Generation Email Lists A1 A2 A3 A4 B1 B2 B3 B4 C1 C2 C3 C4 D1 D2 D3 D4 E1 E2 E3 E4 F1 F2 F3 F4 G1 G2 G3 G4 H1 H2 H3 H4 I1 I2 I3 I4 J1 J2 J3 J4 K1 K2 K3 K4 L1 L2 L3 L4 M1 M2 M3 M4 N1 N2 N3 N4 O1 O2 O3 O4 P1 P2 P3 P4 Q1 Q2 Q3 Q4 R1 R2 R3 R4 S1 S2 S3 S4 T1 T2 T3 T4 U1 U2 U3 U4 V1 V2 V3 V4 W1 W2 W3 W4 X1 X2 X3 X4 Y1 Y2 Y3 Y4 Z1 Z2 Z3 Z4 Product Features Our Data Pricing Use Cases Sales Recruiters Use Cases Sales Recruiters Features Search Portal Email Campaigns Chrome Extension Company About Us Careers Contact Us Customer Stories Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info Resources Blog Guides Knowledge Base Video Tutorials ContactOut Alternatives Legal Terms of Use Privacy Privacy Policy Do Not', metadata={'source': 'https://contactout.com/search-portal'}),
#  Document(page_content='Stories Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info Resources Blog Guides Knowledge Base Video Tutorials ContactOut Alternatives Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info', metadata={'source': 'https://contactout.com/search-portal'}),
#  Document(page_content='Use Cases Sales Unlimited sales users for $299 Recruiters Speed up hiring of top talents Features Search Portal Find the right prospects quickly with 20+ search filters Email Campaigns Automate & accelerate your outreach Chrome Extension Supercharge your prospecting on LinkedIn and across the the web Integrations Power up your existing tools with ContactOut data Data Enrichment Know your leads in minutes with ContactOut data API Integrate ContactOut data into your workflow Use Cases Sales Recruiters Features Search Portal Email Campaigns Chrome Extension Integrations Data Enrichment API Our Data Clients Pricing Support Guides Get a demo Login Sign up for free Login Contact us Remove my data Need to opt-out or revise the information about me in ContactOut? Opt-out request Support: [email protected] Sales inquiries: [email protected] 934 Howard St San Francisco, CA 94103 United States FAQ Does ContactOut work on multiple browsers? At this time ContactOut works exclusively with Google', metadata={'source': 'https://contactout.com/contact'}),
#  Document(page_content="protected] Sales inquiries: [email protected] 934 Howard St San Francisco, CA 94103 United States FAQ Does ContactOut work on multiple browsers? At this time ContactOut works exclusively with Google Chrome. How can I reset my password? To reset your password select “Forgot Your Password” on the login screen. Enter your email and you will be sent a link to reset your password. I am having trouble using ContactOut. Email [email protected] and tell us what errors you are experiencing. Please be as specific as possible and include a screenshot. How do I verify my account? After you use 5 credits you will be sent a verification email. Simply follow the directions to click the link included in the email and your account will be verified. If you encounter any issues please let us know. Can I be certain that I am given accurate contact information? All emails in our database were triple verified. This means that each contact has passed three tests: Does the email match the correct individual's", metadata={'source': 'https://contactout.com/contact'}),
#  Document(page_content="that I am given accurate contact information? All emails in our database were triple verified. This means that each contact has passed three tests: Does the email match the correct individual's social media profiles? Is the email associated with the correct LinkedIn profile? Can the email pass a bounce test to ensure delivery? How do I opt-out or revise the information about me in ContactOut? Simply fill out this opt-out form and your submission will be processed within one week. Does ContactOut have an API? We are only able to offer API at the Enterprise level. If you are currently negotiating an Enterprise plan please let us know you are interested in API. We are happy to discuss options! How much does ContactOut cost? ContactOut is priced per user at a rate competitive with other high-value recruiting products. Please contact [email protected] How can I cancel my subscription? Cancellations and Refunds MONTHLY: You can cancel your paid monthly plan at any time prior to your next", metadata={'source': 'https://contactout.com/contact'}),
#  Document(page_content='recruiting products. Please contact [email protected] How can I cancel my subscription? Cancellations and Refunds MONTHLY: You can cancel your paid monthly plan at any time prior to your next billing date. When you cancel your plan, you still retain your remaining lookups until your next billing date. To cancel your plan click the MANAGE SUBSCRIPTION button on your account page Or you can email [email protected] ANNUAL: You can cancel your annual subscription within the first 30 days of purchase provided that you have used less than 100 credits. You will be refunded the annual price less the one month price. To cancel your annual subscription email: [email protected] I am an existing customer, how can I get help? If you are an existing customer and have questions on getting set up or how to use the product, please contact [email protected] © 2023 ContactOut. All rights reserved. Directory Email Finder Email Verifier People Search Best Blogger Outreach Recruitment Sales Platforms', metadata={'source': 'https://contactout.com/contact'}),
#  Document(page_content='how to use the product, please contact [email protected] © 2023 ContactOut. All rights reserved. Directory Email Finder Email Verifier People Search Best Blogger Outreach Recruitment Sales Platforms Staffing Lead Generation Talent Acquisition Social Media Marketing Sales Platform Sales Engagement Sales Leads Recruiting Automation B2B Data Revenue Operations Email Verification Email Tracking Account Based Marketing Blogger Outreach Lead Intelligence Marketing Intelligence Diversity Recruiting Sales Software Data Enrichment Identity Verification Technology Lookup Sales Intelligence Sales Tools Staffing Software Email Marketing Market Intelligence Influencer Marketing Recruitment Marketing Link Building SMS Marketing Recruitment Software SEO Tools Content Marketing Sales Prospecting Demand Generation Email Lists A1 A2 A3 A4 B1 B2 B3 B4 C1 C2 C3 C4 D1 D2 D3 D4 E1 E2 E3 E4 F1 F2 F3 F4 G1 G2 G3 G4 H1 H2 H3 H4 I1 I2 I3 I4 J1 J2 J3 J4 K1 K2 K3 K4 L1 L2 L3 L4 M1 M2 M3 M4 N1 N2 N3 N4 O1 O2 O3 O4', metadata={'source': 'https://contactout.com/contact'}),
#  Document(page_content='Email Lists A1 A2 A3 A4 B1 B2 B3 B4 C1 C2 C3 C4 D1 D2 D3 D4 E1 E2 E3 E4 F1 F2 F3 F4 G1 G2 G3 G4 H1 H2 H3 H4 I1 I2 I3 I4 J1 J2 J3 J4 K1 K2 K3 K4 L1 L2 L3 L4 M1 M2 M3 M4 N1 N2 N3 N4 O1 O2 O3 O4 P1 P2 P3 P4 Q1 Q2 Q3 Q4 R1 R2 R3 R4 S1 S2 S3 S4 T1 T2 T3 T4 U1 U2 U3 U4 V1 V2 V3 V4 W1 W2 W3 W4 X1 X2 X3 X4 Y1 Y2 Y3 Y4 Z1 Z2 Z3 Z4 Product Features Our Data Pricing Use Cases Sales Recruiters Use Cases Sales Recruiters Features Search Portal Email Campaigns Chrome Extension Company About Us Careers Contact Us Customer Stories Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info Resources Blog Guides Knowledge Base Video Tutorials ContactOut Alternatives Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info', metadata={'source': 'https://contactout.com/contact'}),
#  Document(page_content='Use Cases Sales Unlimited sales users for $299 Recruiters Speed up hiring of top talents Features Search Portal Find the right prospects quickly with 20+ search filters Email Campaigns Automate & accelerate your outreach Chrome Extension Supercharge your prospecting on LinkedIn and across the the web Integrations Power up your existing tools with ContactOut data Data Enrichment Know your leads in minutes with ContactOut data API Integrate ContactOut data into your workflow Use Cases Sales Recruiters Features Search Portal Email Campaigns Chrome Extension Integrations Data Enrichment API Our Data Clients Pricing Support Guides Get a demo Login Sign up for free Login ContactOut for Recruiters Speed up hiring of top talents Reach the best candidates in half the time with ContactOut. Generate lists of candidates in seconds — the right job title, skills, and industry. Email & call with confidence using triple-verified personal emails and direct dials. Sign up for free Get Chrome extension', metadata={'source': 'https://contactout.com/recruiters'}),
#  Document(page_content='lists of candidates in seconds — the right job title, skills, and industry. Email & call with confidence using triple-verified personal emails and direct dials. Sign up for free Get Chrome extension (it’s free!) Sign up for free Here’s how ContactOut can help you Recruiting Leader Equip your team to grow strong talent pipelines with ContactOut’s accurate candidate data. Stop chasing, and start attracting qualified top talents today. Recruiter / Sourcer Connect with the right candidates with the right contact details and the right message. Focus on engaging with qualified candidates, and start filling more job roles. In-house recruiter / Agency recruiter Connect with top talents with ContactOut quickly. Get more responses, and less bounce backs. Trusted by 1.4M recruiters from Fortune 500 companies Introducing ContactOut for Recruiters Accelerate hiring process, maximise productivity, and fill more positions with ContactOut, the most accurate B2B database. Search Portal Identify ideal', metadata={'source': 'https://contactout.com/recruiters'}),
#  Document(page_content='companies Introducing ContactOut for Recruiters Accelerate hiring process, maximise productivity, and fill more positions with ContactOut, the most accurate B2B database. Search Portal Identify ideal candidates fast Drive better hiring decisions more efficiently and effectively. Find the right talents quickly with 20+ search filters like job titles, locations, skills, technologies used and years of experience. Chrome Extension Accelerate hiring process Book more interviews and fill more positions. Access personal emails and mobile numbers; Add candidates to email campaigns. Directly on LinkedIn Standard, Recruiter Lite and Pro. Email Campaigns Less ‘ghosting’ from candidates Keep potential candidates in the loop. Connect with them on a personal level with the right message at the right time. Improve your campaign success with open, click and reply rates tracking. ATS Integrations Increase efficiency & performance Eliminate tedious repetitive tasks. Save candidate details directly to', metadata={'source': 'https://contactout.com/recruiters'}),
#  Document(page_content='time. Improve your campaign success with open, click and reply rates tracking. ATS Integrations Increase efficiency & performance Eliminate tedious repetitive tasks. Save candidate details directly to your ATS like Lever, Greenhouse and Bullhorn from ContactOut Search Portal and LinkedIn Recruiter via Chrome extension. Data Enrichment & API Shorten recruitment process Contact high-potential candidates with new ATS data refresh. Powered by ContactOut’s triple verification process, you’ll get accurate B2B data for 300M professionals and 30M companies. Hear what our customers have to say “This is such a great and simple tool to use.” Tobia St Germain Google "Find personal mails seamlessly. Thanks for this tool!" Ekin Bayildiran J.P. Morgan “Very easy to use, and it gives contact details that are not available on others I have used.” Barbara Ball Societe Generale “Love it! I use it every day.” Camille Verdier CNN “Great email tool. I\'ve used a few other services and ContactOut is the', metadata={'source': 'https://contactout.com/recruiters'}),
#  Document(page_content="that are not available on others I have used.” Barbara Ball Societe Generale “Love it! I use it every day.” Camille Verdier CNN “Great email tool. I've used a few other services and ContactOut is the easiest one to use.” Jon Nowakowski Robert Half “Excellent product, very small chance of error.” Farida Charania HSBC “This is definitely my preferred extension for finding email addresses. It requires the least amount of effort to help find information needed. Keep up the great work!” Suzanne Huynh PwC “Love this extension and would recommend it to anyone looking for a tool to find email addresses.” Evan M. Wolfson Yelp “Great product! ContactOut has tripled the yield of our InMail strategy on LinkedIn (which isn't delivering us ROI anymore).” Ryan Brogan WarnerMedia “With Lusha you get given a number you don’t know whether it’s right or not. With ContactOut you get the [verified] button — which I really appreciate, ‘cause obviously I’d never call [an unverified] number.” Sophie Hopkins", metadata={'source': 'https://contactout.com/recruiters'}),
#  Document(page_content='a number you don’t know whether it’s right or not. With ContactOut you get the [verified] button — which I really appreciate, ‘cause obviously I’d never call [an unverified] number.” Sophie Hopkins Client Associate, Third Bridge “With Lusha you get given a number you don’t know whether it’s right or not. With ContactOut you get the [verified] button — which I really appreciate, ‘cause obviously I’d never call [an unverified] number.” Sophie Hopkins Client Associate, Third Bridge Read more customer success stories Hear what our customershave to say “This is such a great and simple tool to use.” Tobia St Germain Google "Find personal mails seamlessly. Thanks for this tool!" Ekin Bayildiran JP Morgan “Very easy to use, and it gives contact details that are not available on others I have used.” Barbara Ball Societe Generale “Love it! I use it every day.” Camille Verdier CNN “Great email tool. I\'ve used a few other services and ContactOut is the easiest one to use.” Jon Nowakowski Robert', metadata={'source': 'https://contactout.com/recruiters'}),
#  Document(page_content='Barbara Ball Societe Generale “Love it! I use it every day.” Camille Verdier CNN “Great email tool. I\'ve used a few other services and ContactOut is the easiest one to use.” Jon Nowakowski Robert Half “Excellent product, very small chance of error.” Farida Charania HSBC “This is definitely my preferred extension for finding email addresses.” Suzanne Huynh PwC “Love this extension and would recommend it to anyone looking for a tool to find email addresses.” Evan M. Wolfson Yelp "Great product! ContactOut has tripled the yield of our InMail strategy on LinkedIn." Ryan Brogan WarnerMedia “With Lusha you get given a number you don’t know whether it’s right or not. With ContactOut you get the [verified] button — which I really appreciate, ‘cause obviously I’d never call [an unverified] number.” Sophie Hopkins Client Associate, Third Bridge Read more customer success stories “With ContactOut we’ve been able to source at least 50 excellent candidates a week. ContactOut allowed us to quickly', metadata={'source': 'https://contactout.com/recruiters'}),
#  Document(page_content='Sophie Hopkins Client Associate, Third Bridge Read more customer success stories “With ContactOut we’ve been able to source at least 50 excellent candidates a week. ContactOut allowed us to quickly get candidates in our pipeline and has helped us fill our open roles faster. Not many tools can get you the correct email information, let alone a personal phone number like ContactOut does.” Nick Sanders Recruitment Manager, Spreetail Hired 20 Employees in 3 months using ContactOut >50 Candidates Sourced Per week 6–8 New Hires Monthly Exceed company goal of 4 onboardings per month Read customer story Top-ranked Lead Intelligence solution on G2 Crowd G2 Crowd Ratings Comparison for 8.9 Lead Validation 9.1 Lead Enrichment 8.8 Lead Quality 8.9 Lead Analysis 9.2 Browser Extension 8.5 Lead Validation 8.5 Lead Enrichment 8.3 Lead Quality 8.3 Lead Analysis 8.7 Browser Extension 8.9 Lead Validation 8.8 Lead Enrichment 8.9 Lead Quality 8.7 Lead Analysis 9.3 Browser Extension 7.9 Lead Validation 7.9', metadata={'source': 'https://contactout.com/recruiters'}),
#  Document(page_content='8.5 Lead Enrichment 8.3 Lead Quality 8.3 Lead Analysis 8.7 Browser Extension 8.9 Lead Validation 8.8 Lead Enrichment 8.9 Lead Quality 8.7 Lead Analysis 9.3 Browser Extension 7.9 Lead Validation 7.9 Lead Enrichment 7.9 Lead Quality 7.7 Lead Analysis 8.9 Browser Extension 8.9 Lead Validation 9.1 Lead Enrichment 8.8 Lead Quality 8.9 Lead Analysis 9.2 Browser Extension 8.5 Lead Validation 8.5 Lead Enrichment 8.3 Lead Quality 8.3 Lead Analysis 8.7 Browser Extension 8.9 Lead Validation 8.8 Lead Enrichment 8.9 Lead Quality 8.7 Lead Analysis 9.3 Browser Extension 7.9 Lead Validation 7.9 Lead Enrichment 7.9 Lead Quality 7.7 Lead Analysis 8.9 Browser Extension Compare ContactOut with other vendors Compare ContactOut with other vendors Find top talents, fill positions fast. Accelerate hiring process, maximise productivity, and fill more positions with ContactOut. 40 emails reveals / month 3 phone numbers reveals / month Find work emails, personal emails and mobile numbers Works on LinkedIn', metadata={'source': 'https://contactout.com/recruiters'}),
#  Document(page_content='maximise productivity, and fill more positions with ContactOut. 40 emails reveals / month 3 phone numbers reveals / month Find work emails, personal emails and mobile numbers Works on LinkedIn Standard only for Free Plan 1 user per company limit Sign up for free Get Chrome extension (it’s free!) Sign up for free No credit card required. Cancel anytime. © 2023 ContactOut. All rights reserved. Directory Email Finder Email Verifier People Search Best Blogger Outreach Recruitment Sales Platforms Staffing Lead Generation Talent Acquisition Social Media Marketing Sales Platform Sales Engagement Sales Leads Recruiting Automation B2B Data Revenue Operations Email Verification Email Tracking Account Based Marketing Blogger Outreach Lead Intelligence Marketing Intelligence Diversity Recruiting Sales Software Data Enrichment Identity Verification Technology Lookup Sales Intelligence Sales Tools Staffing Software Email Marketing Market Intelligence Influencer Marketing Recruitment Marketing Link', metadata={'source': 'https://contactout.com/recruiters'}),
#  Document(page_content='Software Data Enrichment Identity Verification Technology Lookup Sales Intelligence Sales Tools Staffing Software Email Marketing Market Intelligence Influencer Marketing Recruitment Marketing Link Building SMS Marketing Recruitment Software SEO Tools Content Marketing Sales Prospecting Demand Generation Email Lists A1 A2 A3 A4 B1 B2 B3 B4 C1 C2 C3 C4 D1 D2 D3 D4 E1 E2 E3 E4 F1 F2 F3 F4 G1 G2 G3 G4 H1 H2 H3 H4 I1 I2 I3 I4 J1 J2 J3 J4 K1 K2 K3 K4 L1 L2 L3 L4 M1 M2 M3 M4 N1 N2 N3 N4 O1 O2 O3 O4 P1 P2 P3 P4 Q1 Q2 Q3 Q4 R1 R2 R3 R4 S1 S2 S3 S4 T1 T2 T3 T4 U1 U2 U3 U4 V1 V2 V3 V4 W1 W2 W3 W4 X1 X2 X3 X4 Y1 Y2 Y3 Y4 Z1 Z2 Z3 Z4 Product Features Our Data Pricing Use Cases Sales Recruiters Use Cases Sales Recruiters Features Search Portal Email Campaigns Chrome Extension Company About Us Careers Contact Us Customer Stories Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info Resources Blog Guides Knowledge Base Video Tutorials ContactOut Alternatives Legal Terms of Use Privacy Privacy', metadata={'source': 'https://contactout.com/recruiters'}),
#  Document(page_content='Us Customer Stories Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info Resources Blog Guides Knowledge Base Video Tutorials ContactOut Alternatives Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info', metadata={'source': 'https://contactout.com/recruiters'}),
#  Document(page_content='Use Cases Sales Unlimited sales users for $299 Recruiters Speed up hiring of top talents Features Search Portal Find the right prospects quickly with 20+ search filters Email Campaigns Automate & accelerate your outreach Chrome Extension Supercharge your prospecting on LinkedIn and across the the web Integrations Power up your existing tools with ContactOut data Data Enrichment Know your leads in minutes with ContactOut data API Integrate ContactOut data into your workflow Use Cases Sales Recruiters Features Search Portal Email Campaigns Chrome Extension Integrations Data Enrichment API Our Data Clients Pricing Support Guides Get a demo Login Sign up for free Login BDEX Ramps up Business Development with ContactOut For us, this is it. We’ve got to use ContactOut. Brain Hathway Vice President of Business Development at BDEX BDEX BDEX, standing for “big data exchange”, is one of the first big data exchange platforms. They sell consumer information to business giants such as Amazon, Estee', metadata={'source': 'https://contactout.com/clients/bdex'}),
# ...
#  Document(page_content='direct dial (mobile phone number) data. Recruiters, salespeople, and marketers make up the majority of ContactOut’s customer base. ContactOut plans start at just $29/mo. There are also free plans, which give you 40 credits per month. One credit = one person’s contact information. Direct dials (mobile number data) are billed separately, and vary by plan. Please see the pricing page for more details. ContactOut has a free plan you can use forever. It comes with 40 credits per month (1 credit = 1 person’s contact details.) The free plan only works with LinkedIn Standard (not LinkedIn Recruiter, Recruiter Lite, or SalesNav.) It also does not give you access to candidate & sales prospect mobile numbers. ContactOut data is 99% accurate, due to our process of triple-verifying each contact via AI and social media. Yes, our data is fully committed and aligned to the GDPR & CCPA requirements. Yes, you can connect Greenhouse, Lever, Salesforce, and thousands of other systems either natively or', metadata={'source': 'https://contactout.com/alternative'}),
#  Document(page_content='AI and social media. Yes, our data is fully committed and aligned to the GDPR & CCPA requirements. Yes, you can connect Greenhouse, Lever, Salesforce, and thousands of other systems either natively or via ContactOut’s partnership with Zapier. ContactOut is known as the provider with the most extensive and accurate data. This is according to independent reviews by users on G2. (Check those reviews here.) Still have questions? Can’t find the answer you’re looking for? Please reach out to our friendly Customer Success team or head over to our Knowledge Base. Get in touch See how ContactOut stacks up Compare ContactOut alternatives to see which is the right product for you. ContactOut vs. Apollo ContactOut vs. Lusha ContactOut vs. ZoomInfo Hire anyone, anywhere with ContactOut today Making remote or global hires? We can help. 40 emails / month 3 phone numbers / month Works on standard LinkedIn only Work emails, personal emails, mobile numbers 1 user per company limit Sign up to get 40 free', metadata={'source': 'https://contactout.com/alternative'}),
#  Document(page_content='or global hires? We can help. 40 emails / month 3 phone numbers / month Works on standard LinkedIn only Work emails, personal emails, mobile numbers 1 user per company limit Sign up to get 40 free credits Get Chrome extension Sign up to get 40 free credits No credit card required. Cancel anytime. © 2023 ContactOut. All rights reserved. Directory Email Finder Email Verifier People Search Best Blogger Outreach Recruitment Sales Platforms Staffing Lead Generation Talent Acquisition Social Media Marketing Sales Platform Sales Engagement Sales Leads Recruiting Automation B2B Data Revenue Operations Email Verification Email Tracking Account Based Marketing Blogger Outreach Lead Intelligence Marketing Intelligence Diversity Recruiting Sales Software Data Enrichment Identity Verification Technology Lookup Sales Intelligence Sales Tools Staffing Software Email Marketing Market Intelligence Influencer Marketing Recruitment Marketing Link Building SMS Marketing Recruitment Software SEO Tools', metadata={'source': 'https://contactout.com/alternative'}),
#  Document(page_content='Lookup Sales Intelligence Sales Tools Staffing Software Email Marketing Market Intelligence Influencer Marketing Recruitment Marketing Link Building SMS Marketing Recruitment Software SEO Tools Content Marketing Sales Prospecting Demand Generation Email Lists A1 A2 A3 A4 B1 B2 B3 B4 C1 C2 C3 C4 D1 D2 D3 D4 E1 E2 E3 E4 F1 F2 F3 F4 G1 G2 G3 G4 H1 H2 H3 H4 I1 I2 I3 I4 J1 J2 J3 J4 K1 K2 K3 K4 L1 L2 L3 L4 M1 M2 M3 M4 N1 N2 N3 N4 O1 O2 O3 O4 P1 P2 P3 P4 Q1 Q2 Q3 Q4 R1 R2 R3 R4 S1 S2 S3 S4 T1 T2 T3 T4 U1 U2 U3 U4 V1 V2 V3 V4 W1 W2 W3 W4 X1 X2 X3 X4 Y1 Y2 Y3 Y4 Z1 Z2 Z3 Z4 Product Features Our Data Pricing Use Cases Sales Recruiters Use Cases Sales Recruiters Features Search Portal Email Campaigns Chrome Extension Company About Us Careers Contact Us Customer Stories Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info Resources Blog Guides Knowledge Base Video Tutorials ContactOut Alternatives Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info', metadata={'source': 'https://contactout.com/alternative'}),
#  Document(page_content='Use Cases Sales Unlimited sales users for $299 Recruiters Speed up hiring of top talents Features Search Portal Find the right prospects quickly with 20+ search filters Email Campaigns Automate & accelerate your outreach Chrome Extension Supercharge your prospecting on LinkedIn and across the the web Integrations Power up your existing tools with ContactOut data Data Enrichment Know your leads in minutes with ContactOut data API Integrate ContactOut data into your workflow Use Cases Sales Recruiters Features Search Portal Email Campaigns Chrome Extension Integrations Data Enrichment API Our Data Clients Pricing Support Guides Get a demo Login Sign up for free Login ContactOut vs. Lusha for Recruiters 📇 CCPA Compliant GDPR Compliant Sign up for free No credit card required Introduction ContactOut as a Lusha Alternative — a strong Lusha competitor ✨ Mate — this one’s a no-brainer. Although Lusha claims to be “much better,” ContactOut’s G2 ratings speak for themselves. Across the board,', metadata={'source': 'https://contactout.com/alternative/lusha-vs-contactout'}),
#  Document(page_content='as a Lusha Alternative — a strong Lusha competitor ✨ Mate — this one’s a no-brainer. Although Lusha claims to be “much better,” ContactOut’s G2 ratings speak for themselves. Across the board, in every way, we are, in their words, “much better.” And not only are we wiping the floor with our stats and G2 ratings, Lusha doesn’t have any proprietary data or engagement tools. If you’re a recruiter, ContactOut is the obvious choice. Riddle me this — with the average tenure of a tech nerd being 1.5 – 2 years, what’s the point in having work emails if it’s going to be useless in the next year or so? And if that’s not enough to convince you, we’re more affordable with a lower per credit cost. Book a demo 150M Personal Emails 30M Personal Emails 200M Work Emails 80M Work Emails 100M Phone Numbers 80M Phone Numbers ✓ Engagement Tools Engagement Tools 400K Users from 76% of Fortune 500companies use ContactOut 4.6 / 5 G2 ratings 4.4 / 5 Chrome Store rating Prospect faster with the most accurate', metadata={'source': 'https://contactout.com/alternative/lusha-vs-contactout'}),
#  Document(page_content='80M Phone Numbers ✓ Engagement Tools Engagement Tools 400K Users from 76% of Fortune 500companies use ContactOut 4.6 / 5 G2 ratings 4.4 / 5 Chrome Store rating Prospect faster with the most accurate data ever CCPA Compliant GDPR Compliant Triple-verified with 99% Confidence 150M Personal Emails 200M Work Emails 100M Direct Dials 300M Professional Profiles 30M Company Profiles ContactOut gives recruiters the personal emails Lusha lacks Simply put, Lusha’s personal email data coverage for contacting candidates is weak. You can reach more than 200 million contacts by personal email with ContactOut — about 75% of professionals on Linkedin. Lusha has only 10–20% of that amount of personal email data. Better yet, you still get all the professional emails Lusha has — all for the same price. Filter & search millions more profiles in ContactOut Search vs. Lusha ContactOut Search has 100 million more candidate profiles than Lusha — as well as full contact data. Use all the search filters you’re', metadata={'source': 'https://contactout.com/alternative/lusha-vs-contactout'}),
#  Document(page_content='& search millions more profiles in ContactOut Search vs. Lusha ContactOut Search has 100 million more candidate profiles than Lusha — as well as full contact data. Use all the search filters you’re used to in LinkedIn Recruiter and export thousands of records in seconds. ContactOut allows more profile enrichment data than Lusha With ContactOut Enrichment you can enrich millions more candidate profiles by just providing a list of LinkedIn URLs — something that is not possible with Lusha. Each enrichment instantly provides personal email and available phone numbers. ContactOut allows more connections to ATS than Lusha While Lusha only allows connections to a handful of ATS, ContactOut has thousands of integration partners, including Lever, Greenhouse, and Bullhorn. The ContactOut partnership with Zapier means you can integrate contact data into nearly any platform. User reviews on ContactOut vs. Lusha Read what other companies like yours say about why they chose ContactOut, and their', metadata={'source': 'https://contactout.com/alternative/lusha-vs-contactout'}),
#  Document(page_content='with Zapier means you can integrate contact data into nearly any platform. User reviews on ContactOut vs. Lusha Read what other companies like yours say about why they chose ContactOut, and their experience using it. ContactOut customer reviews 📢 Read what other companies like yours say about why they chose ContactOut, and their experience using it. Learn more → Group M In-house Executive Recruitment "You can find tools that will give you a free trial, but I need that level of reliability that comes with ContactOut. It has comprehensive coverage." Read case study Worth Search Recruitment Agency "I was suggested ContactOut by someone who runs a similar business and they tried multiple tools. They found ContactOut to be the right fit." Read case study Ivy Exec Expert Network "ContactOut has provided us with the ability to connect with the Experts we need, in a more seamless and timely manner." Read case study Spreetail In-house Tech Recruitment "With ContactOut we’ve been able to source', metadata={'source': 'https://contactout.com/alternative/lusha-vs-contactout'}),
#  Document(page_content='provided us with the ability to connect with the Experts we need, in a more seamless and timely manner." Read case study Spreetail In-house Tech Recruitment "With ContactOut we’ve been able to source at least 50 excellent candidates a week." Read case study BDEX Business Development "For us, this is it. We’ve got to use ContactOut." Read case study TXT International Executive Search "ContactOut helps us speak to candidates that we otherwise would not be able to reach via social media" Read case study ContractRecruiter Recruitment Agency "ContactOut has allowed us to stay ahead of the competition and deliver outstanding candidates to our clients." Read case study The Power Hive Recruitment Agency "You’ve got to go try something as simple and accurate as ContactOut." Read case study 10x your recruitment & sales conversations Reveal personal & work email addresses, as well as phone numbers accurately with our ContactOut Chrome extension. Sign up for free Frequently asked questions', metadata={'source': 'https://contactout.com/alternative/lusha-vs-contactout'}),
#  Document(page_content='10x your recruitment & sales conversations Reveal personal & work email addresses, as well as phone numbers accurately with our ContactOut Chrome extension. Sign up for free Frequently asked questions Everything you need to know about the product and billing. ContactOut has about 75% of professionals’ personal and work emails, as well as 70% of professionals’ direct dial (mobile phone number) data. Recruiters, salespeople, and marketers make up the majority of ContactOut’s customer base. ContactOut plans start at just $29/mo. There are also free plans, which give you 40 credits per month. One credit = one person’s contact information. Direct dials (mobile number data) are billed separately, and vary by plan. Please see the pricing page for more details. ContactOut has a free plan you can use forever. It comes with 40 credits per month (1 credit = 1 person’s contact details.) The free plan only works with LinkedIn Standard (not LinkedIn Recruiter, Recruiter Lite, or SalesNav.) It also', metadata={'source': 'https://contactout.com/alternative/lusha-vs-contactout'}),
#  Document(page_content='use forever. It comes with 40 credits per month (1 credit = 1 person’s contact details.) The free plan only works with LinkedIn Standard (not LinkedIn Recruiter, Recruiter Lite, or SalesNav.) It also does not give you access to candidate & sales prospect mobile numbers. ContactOut data is 99% accurate, due to our process of triple-verifying each contact via AI and social media. Yes, our data is fully committed and aligned to the GDPR & CCPA requirements. Yes, you can connect Greenhouse, Lever, Salesforce, and thousands of other systems either natively or via ContactOut’s partnership with Zapier. ContactOut is known as the provider with the most extensive and accurate data. This is according to independent reviews by users on G2. (Check those reviews here.) Still have questions? Can’t find the answer you’re looking for? Please reach out to our friendly Customer Success team or head over to our Knowledge Base. Get in touch See how ContactOut stacks up Compare ContactOut alternatives to', metadata={'source': 'https://contactout.com/alternative/lusha-vs-contactout'}),
#  Document(page_content='the answer you’re looking for? Please reach out to our friendly Customer Success team or head over to our Knowledge Base. Get in touch See how ContactOut stacks up Compare ContactOut alternatives to see which is the right product for you. ContactOut vs. Apollo ContactOut vs. ZoomInfo ContactOut Alternatives Hire anyone, anywhere with ContactOut today Making remote or global hires? We can help. 40 emails / month 3 phone numbers / month Works on standard LinkedIn only Work emails, personal emails, mobile numbers 1 user per company limit Sign up to get 40 free credits Get Chrome extension Sign up to get 40 free credits No credit card required. Cancel anytime. © 2023 ContactOut. All rights reserved. Directory Email Finder Email Verifier People Search Best Blogger Outreach Recruitment Sales Platforms Staffing Lead Generation Talent Acquisition Social Media Marketing Sales Platform Sales Engagement Sales Leads Recruiting Automation B2B Data Revenue Operations Email Verification Email', metadata={'source': 'https://contactout.com/alternative/lusha-vs-contactout'}),
#  Document(page_content='Platforms Staffing Lead Generation Talent Acquisition Social Media Marketing Sales Platform Sales Engagement Sales Leads Recruiting Automation B2B Data Revenue Operations Email Verification Email Tracking Account Based Marketing Blogger Outreach Lead Intelligence Marketing Intelligence Diversity Recruiting Sales Software Data Enrichment Identity Verification Technology Lookup Sales Intelligence Sales Tools Staffing Software Email Marketing Market Intelligence Influencer Marketing Recruitment Marketing Link Building SMS Marketing Recruitment Software SEO Tools Content Marketing Sales Prospecting Demand Generation Email Lists A1 A2 A3 A4 B1 B2 B3 B4 C1 C2 C3 C4 D1 D2 D3 D4 E1 E2 E3 E4 F1 F2 F3 F4 G1 G2 G3 G4 H1 H2 H3 H4 I1 I2 I3 I4 J1 J2 J3 J4 K1 K2 K3 K4 L1 L2 L3 L4 M1 M2 M3 M4 N1 N2 N3 N4 O1 O2 O3 O4 P1 P2 P3 P4 Q1 Q2 Q3 Q4 R1 R2 R3 R4 S1 S2 S3 S4 T1 T2 T3 T4 U1 U2 U3 U4 V1 V2 V3 V4 W1 W2 W3 W4 X1 X2 X3 X4 Y1 Y2 Y3 Y4 Z1 Z2 Z3 Z4 Product Features Our Data Pricing Use Cases Sales', metadata={'source': 'https://contactout.com/alternative/lusha-vs-contactout'}),
#  Document(page_content='N3 N4 O1 O2 O3 O4 P1 P2 P3 P4 Q1 Q2 Q3 Q4 R1 R2 R3 R4 S1 S2 S3 S4 T1 T2 T3 T4 U1 U2 U3 U4 V1 V2 V3 V4 W1 W2 W3 W4 X1 X2 X3 X4 Y1 Y2 Y3 Y4 Z1 Z2 Z3 Z4 Product Features Our Data Pricing Use Cases Sales Recruiters Use Cases Sales Recruiters Features Search Portal Email Campaigns Chrome Extension Company About Us Careers Contact Us Customer Stories Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info Resources Blog Guides Knowledge Base Video Tutorials ContactOut Alternatives Legal Terms of Use Privacy Privacy Policy Do Not Sell My Info', metadata={'source': 'https://contactout.com/alternative/lusha-vs-contactout'})]

# %%
# # Define embedding model
# OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# store = Chroma.from_documents(
#     data_split, embeddings, collection_name="cto", persist_directory="db"
# )

# store.persist()
# store = None
# Out:
# Using embedded DuckDB with persistence: data will be stored in: db

# %% [markdown]
# ### Chroma DB persisted

# %%
# Define embedding model
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)
store = Chroma(
    collection_name="cto", persist_directory="db", embedding_function=embeddings
)
store._collection
# Out:
# Using embedded DuckDB with persistence: data will be stored in: db
# Collection(name=cto)
